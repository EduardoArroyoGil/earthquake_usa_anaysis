# %%
import pandas as pd
pd.options.display.max_columns = None

import sqlalchemy as alch
from sqlalchemy.exc import SQLAlchemyError

from getpass import getpass # secure system to manage passwords

from tqdm import tqdm

# %%
class Load:
    
    def __init__(self, db_name, password_db):

        # nuestra clase va a recibir dos parámetros que son fijos a lo largo de toda la BBDD, el nombre de la BBDD y la contraseña con el servidor. 
        self.db_name = db_name
        self.password_db = password_db

    def server_connection(self): 
        connection = f"mysql+pymysql://root:{self.password_db}@localhost"
        return alch.create_engine(connection)


    def create_db(self):
        engine = self.server_connection()
        try:
            engine.execute(f"CREATE DATABASE IF NOT EXISTS {self.db_name};")
            
        except:
            print("DB already exists")

    def db_connection(self):

        connection2 = f"mysql+pymysql://root:{self.password_db}@localhost/{self.db_name}"
        return alch.create_engine(connection2)

    def create_insert_table(self, query):
        engine = self.db_connection()

    
        try:
            engine.execute(query)
          
        except SQLAlchemyError as e:
            error = str(e.__dict__['orig'])
            return error

    def get_id(self, link, col_id,  column, table):
        
        engine = self.db_connection()
        
        try:
            query_get_id = f"SELECT {col_id} FROM {table} WHERE {column} = '{link}'"

            id_ = engine.execute(query_get_id).first()
 
            if not id_:
                return "id is not in DB"
            else:
                return engine.execute(query_get_id).first()[0]
        
        except SQLAlchemyError as e:
            error = str(e.__dict__['orig'])
            return error

# %%
password_db = getpass("Contraseña de MySQL: ")
# Out:
# Contraseña de MySQL: ········

# %%
earthquakes = Load("earthquakes", password_db)
earthquakes.create_db()
# Out:
# DB already exists

# %%
create_table_earthquakes = '''
CREATE TABLE IF NOT EXISTS `earthquakes`.`f_earthquakes` (
 `id_earthquake`		VARCHAR(36)
, `key_earthquake_gdp`	VARCHAR(36)
, `time`  				TIMESTAMP
, `year`				YEAR
, `latitude` 			FLOAT 
, `longitude` 			FLOAT
, `depth` 				FLOAT
, `mag` 				FLOAT
, `magType` 			TEXT
, `nst`					FLOAT
, `gap`					FLOAT
, `dmin`				FLOAT
, `rms`					FLOAT
, `net`					TEXT
, `id`					TEXT
, `place`				TEXT
, `type`				TEXT
, `horizontalError`		FLOAT
, `depthError`			FLOAT
, `magError`			FLOAT
, `magNst`				FLOAT
, `status`				TEXT
, `locationSource`		TEXT
, `magSource`			TEXT
, `updated_date`		TIMESTAMP
, `inserted_date`		TIMESTAMP
, PRIMARY KEY (`id_earthquake`)
, INDEX `fk_idx_key_earthquake_gdp`(`key_earthquake_gdp` ASC));

'''

# %%
create_table_gdp = '''
CREATE TABLE IF NOT EXISTS `earthquakes`.`f_gdp` (
`id_gdp`				VARCHAR(36)
, `key_gdp_earthquake`	VARCHAR(36)
, `year`				YEAR
, `gdp`					FLOAT
, `state_code`			VARCHAR(2)
, `state_name`			TEXT
, `longitude`			FLOAT
, `latitude`			FLOAT
, `inserted_date`		TIMESTAMP
, PRIMARY KEY (`id_gdp`)
, INDEX `fk_idx_key_earthquake_gdp`(`key_gdp_earthquake` ASC));
'''

# %%
earthquakes.create_insert_table(create_table_earthquakes)

earthquakes.create_insert_table(create_table_gdp)

# %%
def date_to_string(date):
    date_str = str(date)
    t = date[:10]
    z = date[11:19]
    return t+ ' ' +z

# %%
date_to_string('2017-01-20T00:31:18.472Z')
# Out:
# '2017-01-20 00:31:18'

# %%
f_earthquakes = pd.read_parquet('../data/extraction_layer/f_earthquakes.parquet', engine='fastparquet')

# %%
f_earthquakes['updated_date']=f_earthquakes.apply(lambda my_data: date_to_string(my_data['updated_date']), axis = 1)
f_earthquakes['time']=f_earthquakes.apply(lambda my_data: date_to_string(my_data['time']), axis = 1)

# %%
f_earthquakes_sample = f_earthquakes.sample(10)

# %%
f_earthquakes_sample.dtypes
# Out:
# id_earthquake          object
# key_earthquake_gdp     object
# time                   object
# year                    int64
# latitude              float64
# longitude             float64
# depth                 float64
# mag                   float64
# magType                object
# nst                   float64
# gap                   float64
# dmin                  float64
# rms                   float64
# net                    object
# id                     object
# place                  object
# type                   object
# horizontalError       float64
# depthError            float64
# magError              float64
# magNst                float64
# status                 object
# locationSource         object
# magSource              object
# updated_date           object
# dtype: object

# %%
f_earthquakes_sample
# Out:
#                                 id_earthquake  \
# 1569555  5cf5bd55-9622-5883-a2b9-0c3a1afe68e2
# 2235436  b69a08b0-00c3-51c2-9f01-7dc1ffea79dd
# 2702318  78448a92-f3d0-5a0f-9d9d-5ee303663ea3
# 2564238  c0837e0a-d8d4-55ec-aa11-20010a28522b
# 3197554  1d4d2a0e-88a4-52ca-8bbd-6753c2e84d3e
# 582777   ef2ea9c9-794a-5f06-9b84-03c2488e5cd6
# 1613764  7f846d1d-823d-563a-bd06-b943ab6d0a8f
# 1284744  5fe22b4a-c936-5977-b0e9-54cb7dae39d5
# 1581965  3d08e4e3-6cdb-5cee-86e6-01390ebb8ef3
# 2238754  65de4a73-61b1-52d9-bdab-428d69fa5c2b
#
#                            key_earthquake_gdp                 time  year  \
# 1569555  91e2f437-4dc7-5c8a-8d98-384cc18641d5  2004-03-03 16:30:05  2004
# 2235436  cffd859c-7582-50e5-997c-07abaf7e3ca2  2010-07-18 20:53:10  2010
# 2702318  ecbbedd0-8c5a-5b8c-9731-2406946aaed7  2014-09-17 10:06:12  2014
# 2564238  897aa45d-02bd-57a2-a023-b2777e34d919  2013-08-09 03:12:04  2013
# 3197554  fb506b74-2556-5736-b27f-d90d8ad2c209  2018-09-10 00:46:19  2018
# 582777   853a97e7-d04b-5fb6-a9b8-ac963d226f57  1990-03-07 05:03:53  1990
# 1613764  6e58b97e-6a30-58fb-803d-f0e5f332d191  2004-07-25 03:07:03  2004
# 1284744  965e939c-10f0-5607-800e-0cd621b1d343  2000-12-10 05:58:32  2000
# 1581965  4642e8b6-a8b6-5931-90f7-a407a019a2a2  2004-04-11 09:48:38  2004
# 2238754  aaefad2b-5463-536c-902a-2bbcea8d54e0  2010-07-24 10:03:11  2010
#
#           latitude   longitude    depth   mag magType   nst    gap     dmin  \
# 1569555 -34.845000  -70.849000  107.200  2.80      md  12.0  288.5      NaN
# 2235436  52.501700 -168.834700   10.000  2.90      ml   NaN    NaN      NaN
# 2702318  47.561333 -123.009167   16.201  3.98      ml  64.0   72.0  0.06053
# 2564238  38.815834 -122.820503    3.180  0.56      md   9.0   86.0  0.00991
# 3197554  37.604833 -118.942167    0.510  1.29      md  23.0   97.0  0.01859
# 582777   35.302000 -118.545000    2.559  1.71      mc   0.0   90.8      NaN
# 1613764  61.041800 -150.804500   41.000  1.40      ml   NaN    NaN      NaN
# 1284744  44.801500 -110.695667    4.700  1.37      md   7.0  265.0  0.08679
# 1581965 -31.493000  -71.531000   27.500  2.80      ml   7.0  214.8      NaN
# 2238754  46.201333 -122.181167    2.314 -0.70      md  10.0  143.0      NaN
#
#           rms net            id                                         place  \
# 1569555   NaN  us    usp000cp0b  Libertador General Bernardo O'Higgins, Chile
# 2235436  0.28  ak  ak01095g6458         Fox Islands, Aleutian Islands, Alaska
# 2702318  0.39  uw    uw60881241               16km WSW of Seabeck, Washington
# 2564238  0.05  nc    nc72045701             7km NW of The Geysers, California
# 3197554  0.04  nc    nc73082810                   5km SE of Mammoth Lakes, CA
# 582777   0.10  ci     ci1054481                     21km NNW of Tehachapi, CA
# 1613764  0.68  ak  ak0049ie2nci                               Southern Alaska
# 1284744  0.08  uu    uu50215220            Yellowstone National Park, Wyoming
# 1581965   NaN  us    usp000cs85                               Coquimbo, Chile
# 2238754  0.12  uw    uw10799568             Mount St. Helens area, Washington
#
#                type  horizontalError  depthError  magError  magNst     status  \
# 1569555  earthquake              NaN         NaN       NaN     NaN   reviewed
# 2235436  earthquake              NaN       0.000       NaN     NaN   reviewed
# 2702318  earthquake            0.470       0.790     0.206   249.0   reviewed
# 2564238  earthquake            0.630       1.090       NaN     1.0  automatic
# 3197554  earthquake            0.230       0.260     0.315    20.0   reviewed
# 582777   earthquake              NaN       0.015       NaN     8.0   reviewed
# 1613764  earthquake              NaN       2.500       NaN     NaN   reviewed
# 1284744  earthquake            1.490       0.550       NaN     3.0   reviewed
# 1581965  earthquake              NaN         NaN       NaN     NaN   reviewed
# 2238754  earthquake            0.708       0.770     0.010     3.0   reviewed
#
#         locationSource magSource         updated_date
# 1569555            guc       guc  2014-11-07 01:21:37
# 2235436             ak        ak  2018-07-06 21:05:16
# 2702318             uw        uw  2016-07-22 19:38:11
# 2564238             nc        nc  2017-02-01 07:48:53
# 3197554             nc        nc  2018-09-10 22:47:02
# 582777              ci        ci  2016-02-04 23:48:09
# 1613764             ak        ak  2019-02-13 01:26:01
# 1284744             uu        uu  2018-08-28 18:17:15
# 1581965            guc       guc  2014-11-07 01:21:57
# 2238754             uw        uw  2016-07-22 17:10:23

# %%
fields_param_lst = []
fields_lst = []
for ele in f_earthquakes_sample.columns:
    if f_earthquakes_sample[ele].dtypes == 'object':
        fields_param_lst.append("{quote}"+'{row["'+f"{ele}"+'"]}'+"{quote}")
    else:
        fields_param_lst.append('{row["'+f"{ele}"+'"]}')
    fields_lst.append(ele)


fields_param = ", ".join(fields_param_lst)
fields = ", ".join(fields_lst)

# %%
fields_param
# Out:
# '{quote}{row["id_earthquake"]}{quote}, {quote}{row["key_earthquake_gdp"]}{quote}, {quote}{row["time"]}{quote}, {row["year"]}, {row["latitude"]}, {row["longitude"]}, {row["depth"]}, {row["mag"]}, {quote}{row["magType"]}{quote}, {row["nst"]}, {row["gap"]}, {row["dmin"]}, {row["rms"]}, {quote}{row["net"]}{quote}, {quote}{row["id"]}{quote}, {quote}{row["place"]}{quote}, {quote}{row["type"]}{quote}, {row["horizontalError"]}, {row["depthError"]}, {row["magError"]}, {row["magNst"]}, {quote}{row["status"]}{quote}, {quote}{row["locationSource"]}{quote}, {quote}{row["magSource"]}{quote}, {quote}{row["updated_date"]}{quote}'

# %%
def fstr(template):
    return eval(f"f'{template}'")

# %%
for index, row in f_earthquakes.iterrows():
    
    quote = '"'
    
    # creating the query to insert values into table
    query_insert= "INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});"
    
    query_insert_eval = fstr(fstr(query_insert)).replace("nan", "null")
    
    id_link = earthquakes.get_id( f'{row["id_earthquake"]}', "id_earthquake" , "id_earthquake", "f_earthquakes")
    
    if id_link == 'id is not in DB' : 
        earthquakes.create_insert_table(query_insert_eval)
        
    else:
        print('id: ',{row['id_earthquake']}, " is already in DB")
# Out:
# id:  {'43fec453-3c28-55ef-a9fd-8a5c211bf522'}  is already in DB
# id:  {'bddd8dee-6334-5f1d-ad04-35df5563c6d8'}  is already in DB
# id:  {'cd5b0e06-c90e-548b-91db-9cab0e310779'}  is already in DB
# id:  {'b83bf800-775e-511a-a2d5-5b97904bfab5'}  is already in DB
# id:  {'c663dac2-a86e-5ed0-842d-d8fcf256fe47'}  is already in DB
# id:  {'299181b2-3177-571c-86db-b3f5d948add1'}  is already in DB
# id:  {'00867f18-92fe-585e-8901-7fb0ce44bf80'}  is already in DB
# id:  {'6abdf06e-c109-5ab6-b8aa-18acabbc141e'}  is already in DB
# id:  {'f5b1652f-a7a2-590e-93ad-d330abe70889'}  is already in DB
# id:  {'a37a07b3-d66d-578e-9bca-adc7d994327a'}  is already in DB
# id:  {'dbde21bc-d4e6-584a-96e5-8fa6c1362460'}  is already in DB
# id:  {'414e9d64-1278-5361-abd5-9b4c8365d08d'}  is already in DB
# id:  {'91a6ca17-e554-5d28-bf02-f6938c354a61'}  is already in DB
# id:  {'aec2c60a-895e-5be8-8735-4cab06987966'}  is already in DB
# id:  {'7134cbb3-585c-5119-ab0d-5b9f45c6d930'}  is already in DB
# id:  {'775da125-9433-5bc3-871c-b4c862f2c3dd'}  is already in DB
# id:  {'ab3e7850-0340-51ec-9ce5-f9d3d51b5d06'}  is already in DB
# id:  {'6492b7c7-9f7e-5612-a9b9-951b874e9f63'}  is already in DB
# id:  {'8328ccaf-5b72-57d2-8f89-7ef220f5046f'}  is already in DB
# id:  {'202821bc-177e-5602-b45f-28393aeda2ac'}  is already in DB
# id:  {'ee682760-98e8-57d4-b337-572dac50ba4c'}  is already in DB
# id:  {'12d0551b-f4cb-528d-8e41-9e5e63d13f92'}  is already in DB
# id:  {'599ec15e-9c3d-568d-bae7-6217e19e047d'}  is already in DB
# id:  {'824384cb-0990-59c9-ac18-277dd18eeed5'}  is already in DB
# id:  {'527fe4b2-29dc-586d-a1d7-ef4809da3cd5'}  is already in DB
# id:  {'86723b08-a5ee-5fe6-9303-ec07ccc67cbf'}  is already in DB
# id:  {'c31d0a4b-f284-5bf0-86a8-e461674fbbe9'}  is already in DB
# id:  {'e1c6846d-98ee-5ee2-8d9e-72fd8e9ba928'}  is already in DB
# id:  {'c7a8c9e3-f79a-5cef-bb6c-5c50d4e97729'}  is already in DB
# id:  {'43e11e30-5fee-5f2f-8be9-d17b6ff8acfd'}  is already in DB
# id:  {'91bc2db0-1283-57e1-adc6-d2f8deee705a'}  is already in DB
# id:  {'2435a079-da5f-5ae3-8b44-cc0baedb48d2'}  is already in DB
# id:  {'41438e70-f814-5084-ae30-a0f83ef037ec'}  is already in DB
# id:  {'7b1ef4b7-6c3e-544b-ab9e-a0c4d3e52053'}  is already in DB
# id:  {'68a354a6-5053-5e57-b924-758e89be5d77'}  is already in DB
# id:  {'0ecfb4aa-11f8-5371-a8c3-6117d8eb6cf5'}  is already in DB
# id:  {'fb041d9b-411b-568a-9b26-6e9db982453f'}  is already in DB
# id:  {'d32b180a-6349-5777-ac6b-2bcf45ac5f17'}  is already in DB
# id:  {'b7012b41-4fb7-5cda-8fd9-9ddf74160be4'}  is already in DB
# id:  {'50fcf725-9c0d-55c5-b989-c50db7c0c234'}  is already in DB
# id:  {'687d8017-e474-5590-9134-46ce69beb153'}  is already in DB
# id:  {'9c6f13af-ddbf-5b0b-90d2-064e157860d0'}  is already in DB
# id:  {'cc4fef5f-936c-5aa3-9b49-c50429abc54c'}  is already in DB
# id:  {'6b450102-ca20-5883-ab1d-4f5df0907b90'}  is already in DB
# id:  {'4cff818a-de5f-53db-b95c-121119c9b8c0'}  is already in DB
# id:  {'81fb234f-d761-5867-af0a-25cb432cb730'}  is already in DB
# id:  {'158b0137-51ac-5d8a-b322-9a45b1f4a448'}  is already in DB
# id:  {'32b44ade-6065-517e-93ad-e6e3ef0428b8'}  is already in DB
# id:  {'e3ff4575-84fb-57b8-9a3c-27d83b7c9a43'}  is already in DB
# id:  {'60afb44b-07c7-5bb2-92a9-2b56d1833edf'}  is already in DB
# id:  {'d0718e11-84d1-5ecd-83cd-9f5331ee1bd2'}  is already in DB
# id:  {'b4c049cc-a670-55e3-a937-b393824b1a5f'}  is already in DB
# id:  {'80e4d2ab-8f83-5344-8641-5d4758911674'}  is already in DB
# id:  {'38ba03a3-809b-51e6-a3ea-1b7ba3c85625'}  is already in DB
# id:  {'cf2e501d-f94c-53be-ae02-3b41a9c195a3'}  is already in DB
# id:  {'7e5eb7b5-c1ee-5c85-accf-02843c4a6bf3'}  is already in DB
# id:  {'ed63f860-484e-5821-acf6-456ca777e1b1'}  is already in DB
# id:  {'9f09b1a0-a720-5ab6-871f-7cadb52b0b15'}  is already in DB
# id:  {'a3edb1be-6617-5330-b418-71e6fab08d5b'}  is already in DB
# id:  {'89ca0bdf-0d9d-59d7-8806-65a57fa443ee'}  is already in DB
# id:  {'7c2ea320-f38c-5353-80ed-81f26d2934be'}  is already in DB
# id:  {'f4aff9bb-6de0-5bf7-aeee-a5538e76bde7'}  is already in DB
# id:  {'c5d04e13-de2c-5759-a9f9-1c651d6884dd'}  is already in DB
# id:  {'4ea45b79-44eb-5829-9e55-13db5afaa0b2'}  is already in DB
# id:  {'e88cd6de-a764-53d0-a730-8fd099e05bdd'}  is already in DB
# id:  {'439d1456-e475-5ea4-ae90-2f501501935a'}  is already in DB
# id:  {'3ee1f55a-0d88-52c3-ab2e-b22ac494e7b9'}  is already in DB
# id:  {'b091ca29-64f4-568a-94e0-d88b9f803cad'}  is already in DB
# id:  {'b3505056-5fdc-59ad-b45f-2baa1bd664c8'}  is already in DB
# id:  {'7684dafb-37ca-5357-b9ad-29e72268f287'}  is already in DB
# id:  {'a1befd1a-e344-5d3f-abe3-71c38b055a4e'}  is already in DB
# id:  {'858a7fb2-149a-53bd-943d-d265d504c5ae'}  is already in DB
# id:  {'3524c3e8-5f17-5b61-a0ad-9f5276c62e54'}  is already in DB
# id:  {'8aa70aa9-84ac-5097-8eec-06f206adbac9'}  is already in DB
# id:  {'371f55e2-9112-5e3c-af45-72baac1be3fa'}  is already in DB
# id:  {'508c1ec3-cc97-5ce7-9338-5aa8c9c8963b'}  is already in DB
# id:  {'dbfa85e7-017a-5e40-b8f0-786250780734'}  is already in DB
# id:  {'7c566dbc-46f4-540e-bc07-5ebd50dde44e'}  is already in DB
# id:  {'3625c10f-5125-5416-9a8d-b3e5c1c24bac'}  is already in DB
# id:  {'5d0d8075-d4af-54aa-b875-4e4043c6602f'}  is already in DB
# id:  {'b5abbb42-48c7-575a-85d2-8ff237962a84'}  is already in DB
# id:  {'698a4e8e-f168-538d-a345-fdbb8db37f09'}  is already in DB
# id:  {'39421ed5-4558-53be-90a1-1f1ca62ecb9a'}  is already in DB
# id:  {'3be1d9cd-995f-5fff-ae5a-b2ad80f4a230'}  is already in DB
# id:  {'ac2e3924-1c89-5f58-818a-ce380268f074'}  is already in DB
# id:  {'41a3b145-a15f-5cc1-a82f-73625533170b'}  is already in DB
# id:  {'a50af309-369b-5a55-9cd5-53b0bb50d62e'}  is already in DB
# id:  {'62bcc184-b395-5e05-bb44-a0edb92a0421'}  is already in DB
# id:  {'f171831f-3fa7-50ae-959f-f8134b9dd3b7'}  is already in DB
# id:  {'9b578955-ef3f-5888-a02a-8c6567508eb4'}  is already in DB
# id:  {'5fc79fda-74e2-52db-89b6-328ac4649539'}  is already in DB
# id:  {'76ff9dc6-7903-57c8-853c-f04c5b98cd84'}  is already in DB
# id:  {'134f185d-3be5-5209-b417-0f3d76203425'}  is already in DB
# id:  {'3f9e9e31-27c3-59e6-9090-53608c66200d'}  is already in DB
# id:  {'f8b4c027-9ffc-542a-bc43-1fc1b9ac79ea'}  is already in DB
# id:  {'ae10f821-3685-52ba-8eda-c158f1585527'}  is already in DB
# id:  {'1cc06ed3-e738-5a3f-ae1c-2a8c3560e5ec'}  is already in DB
# id:  {'fa74614b-54f4-5bad-97b1-6038b9b0bd71'}  is already in DB
# id:  {'7a685fee-8143-5399-9029-b256d10cb5ec'}  is already in DB
# id:  {'8a2235cd-6f53-52bd-be69-17cceb42f354'}  is already in DB
# id:  {'b6448686-b431-5360-9bd9-91a6ef5a6f73'}  is already in DB
# id:  {'e8ed6212-8c1b-504b-9e76-dc1ca32a33fa'}  is already in DB
# id:  {'755ac7ef-43bb-5b18-bb22-f099fb439436'}  is already in DB
# id:  {'c578207a-0965-54fb-a89c-b0369799e5ec'}  is already in DB
# id:  {'122b7402-321a-504e-a7bc-c89c6de8b8ab'}  is already in DB
# id:  {'ec5eda7c-ae1e-52d3-9f56-7d041ee63bd0'}  is already in DB
# id:  {'1f0632a0-8603-5ec5-979a-488dd04135f7'}  is already in DB
# id:  {'86e67c22-be91-5498-b300-94aaa9fbb38c'}  is already in DB
# id:  {'23e796ed-c33e-5d37-93eb-71af2468fd60'}  is already in DB
# id:  {'d15e9790-8172-5931-8abe-46b904fc3034'}  is already in DB
# id:  {'fddf74b1-4019-57ae-ac7f-de6a37317736'}  is already in DB
# id:  {'7f067bff-fe59-5f42-acd8-68ad8da5f9cc'}  is already in DB
# id:  {'91ea1eb3-6db9-55fc-8309-702c03c54152'}  is already in DB
# id:  {'f0f72a2c-b8b7-5137-8bc1-310152b4277f'}  is already in DB
# id:  {'ab6bb00d-deeb-5fb6-a215-a8108075c89f'}  is already in DB
# id:  {'5d99223d-28c3-5ed5-8a79-981a92e2bbd0'}  is already in DB
# id:  {'81522d12-447c-50c5-9d60-27399ca82e1c'}  is already in DB
# id:  {'52e20096-f9ee-5c12-9c03-311bed22c545'}  is already in DB
# id:  {'6afc8030-bb86-587a-8bb0-20f3e4417959'}  is already in DB
# id:  {'2b79cded-6073-59cb-ac8f-6690aa2d956d'}  is already in DB
# id:  {'61aa4c88-d90a-5a05-be26-4daf799ec1b3'}  is already in DB
# id:  {'07f9c8f2-c38b-57cf-9922-838fdc6136d5'}  is already in DB
# id:  {'c6e3c7de-3255-5cc1-be66-5d8011103ef6'}  is already in DB
# id:  {'80ce9449-979d-568e-9c2e-2e4e7cb87699'}  is already in DB
# id:  {'4ac014ac-9ea3-57ae-870b-b1259c727b07'}  is already in DB
# id:  {'b73f12c5-6d00-5d4e-bbb9-e05a28e1b47c'}  is already in DB
# id:  {'9df199b8-18df-5fe8-be17-9e9966dee9d1'}  is already in DB
# id:  {'11f428f9-6b46-5cad-bd34-4e04a67be6be'}  is already in DB
# id:  {'3d0fb068-921e-5006-a397-3b3d8fb0a14b'}  is already in DB
# id:  {'c15c2135-4b6a-567c-9ba0-09682b1803e9'}  is already in DB
# id:  {'e550c9ac-2fc1-50bf-bc0a-7b14f805c15c'}  is already in DB
# id:  {'9fcb7bf5-b48b-59eb-9369-de4b2e22fd44'}  is already in DB
# id:  {'50085094-054f-53d3-8c9c-31c5d76a40fc'}  is already in DB
# id:  {'4ce04e6d-2934-5d9e-ac21-464f15b894cb'}  is already in DB
# id:  {'f153b784-bf45-5ed9-85bd-8190b54786a5'}  is already in DB
# id:  {'733910e9-ca98-5a91-be50-0c8282a424ab'}  is already in DB
# id:  {'8026b18c-4589-5ec2-b7ae-8f398969c692'}  is already in DB
# id:  {'3fb18643-f527-51ff-90b8-bb14ee79a53f'}  is already in DB
# id:  {'68a6f74a-55af-5948-a942-cf3f3ac36dfb'}  is already in DB
# id:  {'527563f8-c9bc-59c5-8832-f46eb5bfaf0d'}  is already in DB
# id:  {'156c7373-56ad-5170-8110-93e77103ea24'}  is already in DB
# id:  {'38afe090-095e-5952-b0d4-3cfe09eab753'}  is already in DB
# id:  {'65005b92-92a8-5004-84f4-7f18ee633058'}  is already in DB
# id:  {'66b5ab78-6bce-5010-a3d2-d5a2ef62e2fb'}  is already in DB
# id:  {'c4986c6e-f744-5584-bdb0-b455e42e2bf8'}  is already in DB
# id:  {'93519409-63fe-574d-a680-bd112cdec1d5'}  is already in DB
# id:  {'53dc3e9b-f9af-594c-8dcd-b63969b5b69b'}  is already in DB
# id:  {'f82e20a3-19d0-5c32-81ae-efacea94f9eb'}  is already in DB
# id:  {'1a0ef57a-d6c6-5085-83ef-46f914d135f9'}  is already in DB
# id:  {'c1a7e608-5951-593d-904d-380a2bc4812a'}  is already in DB
# id:  {'3c1a6687-30ff-5e43-8d9d-81c7dbb9cb3d'}  is already in DB
# id:  {'dc1153e5-1527-5526-879d-9cbce17a5ab4'}  is already in DB
# id:  {'28a4145d-252c-5ab4-802d-1949026ec525'}  is already in DB
# id:  {'06a96e07-e301-515a-9ac2-90e58c596f79'}  is already in DB
# id:  {'a9f887a8-a178-5b91-b3fd-a10dd6f7142d'}  is already in DB
# id:  {'a5ed5b65-3740-5b34-8b3c-e75b55159a9f'}  is already in DB
# id:  {'0ff19223-5588-57a5-9851-468cfa8d6ddf'}  is already in DB
# id:  {'ed4426db-da9d-530f-9eb4-c0508ba55c38'}  is already in DB
# id:  {'e1fae121-142e-553d-a5a4-6dde48d9f2be'}  is already in DB
# id:  {'82e8297f-1f12-5f80-8f1a-94aa9abeda7b'}  is already in DB
# id:  {'c5ff9d6b-b22a-54fd-ba3b-7bdfe31cce53'}  is already in DB
# id:  {'cab1bb1b-0652-5095-9546-d9ea90cb5340'}  is already in DB
# id:  {'f660a2fc-1399-5a78-8735-1d471d8af6b9'}  is already in DB
# id:  {'6b3cab40-82db-591a-b42f-9ed8683e2678'}  is already in DB
# id:  {'b0764986-18c2-5702-935c-150b1a79739a'}  is already in DB
# id:  {'523b4d6b-4037-5fa6-9cbb-8e98794b4f76'}  is already in DB
# id:  {'155eaed3-8901-5832-b426-0121c6f879cb'}  is already in DB
# id:  {'e5824d52-d5d0-5a3b-ae35-938eba98cd2b'}  is already in DB
# id:  {'b14470b8-036a-5c12-8192-776b8a73c8e0'}  is already in DB
# id:  {'d2be9291-8acd-5c63-8243-daf03539a8a4'}  is already in DB
# id:  {'e98293ce-099b-508e-9c70-687cf63ea77c'}  is already in DB
# id:  {'b69e7c58-e95d-5e02-a4fd-f5a3014a332e'}  is already in DB
# id:  {'f342fc12-4379-5ad8-9ac1-e1069704dc6a'}  is already in DB
# id:  {'5302186a-1db4-5874-ba26-3cd42f06b5f5'}  is already in DB
# id:  {'9ec1042d-f7c8-51e2-9e40-3b534ecc6ad4'}  is already in DB
# id:  {'bfadc528-49fa-58ec-a259-a02ad348507e'}  is already in DB
# id:  {'8cee2d46-eb76-560f-9793-100519d49ac2'}  is already in DB
# id:  {'edcba282-733a-52e0-9855-f0cf47459794'}  is already in DB
# id:  {'110742f6-206d-5c39-916e-3f675cdcb14a'}  is already in DB
# id:  {'37713f37-1062-5be5-8e92-1d06772c66d4'}  is already in DB
# id:  {'7fe7eb7b-b0b8-5138-a41f-c21a922b4b76'}  is already in DB
# id:  {'ae1a7475-2a3f-5736-8586-b986da9062dc'}  is already in DB
# id:  {'e5f7e0a5-247d-5fec-8b53-44e5b0ca293c'}  is already in DB
# id:  {'d0ab83f9-c184-5a14-a6e5-118fcd669be5'}  is already in DB
# id:  {'7b4532fb-e6df-50ad-ab35-883ef17c7d81'}  is already in DB
# id:  {'376381ef-3daa-53f8-ad39-6ebcb3a387f7'}  is already in DB
# id:  {'9eaf20e6-09c4-5889-88e6-511dbdbc4f2a'}  is already in DB
# id:  {'2066e6fc-fc06-51b4-9e50-d980eb0a6257'}  is already in DB
# id:  {'2066e6fc-fc06-51b4-9e50-d980eb0a6257'}  is already in DB
# id:  {'82f3a579-8d03-5bf8-b8f1-12da2e121d0b'}  is already in DB
# id:  {'82f3a579-8d03-5bf8-b8f1-12da2e121d0b'}  is already in DB
# id:  {'2b12f4cb-a7f4-5d77-b419-4e8c2d6988b1'}  is already in DB
# id:  {'2b12f4cb-a7f4-5d77-b419-4e8c2d6988b1'}  is already in DB
# id:  {'977d542a-d0b5-54d1-9b83-600cae538271'}  is already in DB
# id:  {'977d542a-d0b5-54d1-9b83-600cae538271'}  is already in DB
# id:  {'4531cdd5-3de4-54e2-b7a8-8b0d7f129872'}  is already in DB
# id:  {'4531cdd5-3de4-54e2-b7a8-8b0d7f129872'}  is already in DB
# id:  {'67d48717-1e9f-5574-981a-aadc59b92656'}  is already in DB
# id:  {'315aa90b-bbdc-5c58-8f72-d81dc2b96497'}  is already in DB
# id:  {'3074cc44-1e22-5dfd-8b38-64f9c64038e6'}  is already in DB
# id:  {'c78e1e5a-c41f-5ad2-9e4b-a5895f0af326'}  is already in DB
# id:  {'4c751412-99ce-585c-9120-568e381431ad'}  is already in DB
# id:  {'7fbf23b1-2fac-5f83-89ba-d05a1274dd47'}  is already in DB
# id:  {'387ef262-2450-5669-838f-bf28c3b73f4c'}  is already in DB
# id:  {'4308b8cc-3092-5f16-9ec2-a51ad9a7c175'}  is already in DB
# id:  {'4e731fc0-49c0-53ff-a4ef-b011200a7d5e'}  is already in DB
# id:  {'a7db2cf9-984a-5021-af1d-6a865d3c0267'}  is already in DB
# id:  {'2ff34ec6-6970-5ed5-9d9a-a8c396ec537e'}  is already in DB
# id:  {'45ed9fc7-c293-5b1a-bb62-2c62dcd638c7'}  is already in DB
# id:  {'1f0568c9-48c4-5f99-acab-6fe02f97f65a'}  is already in DB
# id:  {'318231a0-0d82-5b3a-bfff-b0069472d56d'}  is already in DB
# id:  {'b2bbff5f-030c-58de-999e-688bd1476912'}  is already in DB
# id:  {'2cc5244b-d842-5230-b0f1-058b31acebd7'}  is already in DB
# id:  {'537d21fd-1251-5e90-828e-72dc9f57b44c'}  is already in DB
# id:  {'2ce33dba-56c6-5049-803a-54fc291a6da7'}  is already in DB
# id:  {'bfa4f365-655b-5ac5-bec4-eeca5e20a229'}  is already in DB
# id:  {'c60608e3-12fb-5c7b-aa8d-feef630f7489'}  is already in DB
# id:  {'18d778ff-50b5-5cd5-8584-3b27a6b6905f'}  is already in DB
# id:  {'328307bf-22bb-548c-926b-e5a1a9be4b85'}  is already in DB
# id:  {'eaa4fde1-de95-5d13-8cb1-962d16f787cd'}  is already in DB
# id:  {'1491429b-6bd7-5851-872b-ebd305e548b4'}  is already in DB
# id:  {'ef2b835f-57d1-56d0-a251-f5d367889648'}  is already in DB
# id:  {'dcfc8377-123f-5a14-bf67-0d96b324317a'}  is already in DB
# id:  {'47aa240d-cbc9-5676-a657-882da6e7b585'}  is already in DB
# id:  {'fce9ad54-62ac-5677-b9f9-bbe1871036e0'}  is already in DB
# id:  {'51c714a6-0e7c-5fad-8ff0-4e6cad20463c'}  is already in DB
# id:  {'a2aab23a-d70c-53bc-b784-68374e2b0ab5'}  is already in DB
# id:  {'dc3e4e01-5667-5f96-9d55-790d335db18c'}  is already in DB
# id:  {'e582728a-9b3b-58bb-902e-487876a2717b'}  is already in DB
# id:  {'14a05b79-a231-560e-9afe-89052d34086c'}  is already in DB
# id:  {'edcdf537-6396-5c81-a182-a24aa8f1ed08'}  is already in DB
# id:  {'82513f50-b52b-5b0f-a70e-5c46eb6c53fa'}  is already in DB
# id:  {'ac454240-bb7c-5cff-92c6-008181fdd422'}  is already in DB
# id:  {'8d39e363-9759-581b-b130-c8462e16596c'}  is already in DB
# id:  {'f431cbb4-c342-594c-81f4-9ca170066dbc'}  is already in DB
# id:  {'f5df5620-d3ba-58aa-881c-991e4e46f534'}  is already in DB
# id:  {'07474a51-a948-5fc4-a364-6188bbfdc6ce'}  is already in DB
# id:  {'9a56d51e-cf64-55e7-9572-fa839804c235'}  is already in DB
# id:  {'ddb1a2f7-361a-5575-9fe8-64590707dd49'}  is already in DB
# id:  {'448fb69e-27a6-5980-a7ce-d8e1839a82b2'}  is already in DB
# id:  {'beae6f2c-718c-5c28-914f-33aa7a7c2ff0'}  is already in DB
# id:  {'25ca8860-9e30-5f52-b96d-f1d5a26a0366'}  is already in DB
# id:  {'88aed9b5-c89a-522c-948a-5985621ea576'}  is already in DB
# id:  {'d5e13890-786e-5280-8589-b4e9a9588935'}  is already in DB
# id:  {'f94290ec-1fde-5b78-9b3c-4c9ca0ebf978'}  is already in DB
# id:  {'178d586a-c9c9-52cc-be2e-0a001b213329'}  is already in DB
# id:  {'c53de025-6a92-5a32-81e8-b6a4d2f2dbea'}  is already in DB
# id:  {'7a410ace-703e-5642-b644-e9581abe3ab5'}  is already in DB
# id:  {'2da5e158-4fe2-5ac7-9d04-821174829a94'}  is already in DB
# id:  {'e6635ce7-9416-54b2-96a2-4caabcfd2447'}  is already in DB
# id:  {'99484e8e-3d53-5a75-8c21-ced8bd1eb73a'}  is already in DB
# id:  {'d193e254-318f-50d5-a44e-840ff3e3098b'}  is already in DB
# id:  {'f32b010f-fb5e-5017-8cb0-b1f974fb1556'}  is already in DB
# id:  {'fec8ffda-0012-5f94-ada5-c93befd640b9'}  is already in DB
# id:  {'b6ca253f-359b-53c7-a2a2-dc17c215dbc9'}  is already in DB
# id:  {'6d0e29cd-edd1-5c11-b602-fe0eb45846d6'}  is already in DB
# id:  {'b8cabdaf-29ed-5248-9990-2c91614d07ba'}  is already in DB
# id:  {'7174bb97-25d2-5794-8b33-44503d8b313a'}  is already in DB
# id:  {'70b55a14-9d41-5985-9867-cc3b53ae2b26'}  is already in DB
# id:  {'f394acc2-a965-5aa8-93d6-ad85668b5ab9'}  is already in DB
# id:  {'1efe2ac5-13ed-52e2-b7d5-449c66bef295'}  is already in DB
# id:  {'612fd53b-160e-5cf2-926a-786675c947be'}  is already in DB
# id:  {'a429e0e2-da54-5bfe-bfb5-731eb6f5ffd5'}  is already in DB
# id:  {'0c4cd58f-d172-5fec-a9d6-8eafca772f27'}  is already in DB
# id:  {'fb405d73-de08-51fc-8905-cdac96f8b958'}  is already in DB
# id:  {'b1c53be3-629e-5b31-aad2-0fbc698da975'}  is already in DB
# id:  {'5e093510-f646-511e-bd0b-453bd8cc10c3'}  is already in DB
# id:  {'fd586d7a-775a-5e6d-a813-2b10abbd9748'}  is already in DB
# id:  {'a0d748c6-bb2a-5186-995d-f61835f953ed'}  is already in DB
# id:  {'a7cb1642-ada9-5ab8-a9a8-dddadccfc040'}  is already in DB
# id:  {'4ae50e0a-b285-5583-85e5-53c086f142b5'}  is already in DB
# id:  {'04500c36-1fee-5b68-9cdb-58fd015d8170'}  is already in DB
# id:  {'5b96b4a5-dc24-52d6-aece-fd21ef6a5541'}  is already in DB
# id:  {'08aee929-f894-5f22-a2d5-e13f7a677bcb'}  is already in DB
# id:  {'019a6793-f42b-5341-9524-8d2ffeece1c7'}  is already in DB
# id:  {'64c347dd-cacf-5d97-9629-0435a6d11c68'}  is already in DB
# id:  {'1edaebd9-92a4-5e88-82e3-f3fc9dabd4c4'}  is already in DB
# id:  {'aae8a96f-6a9a-513b-b283-577dbe9d952a'}  is already in DB
# id:  {'9f890c4e-9cc7-5e3f-a58b-34a867c00bc1'}  is already in DB
# id:  {'8aceb3b7-3ce9-57ec-93e5-10055f953535'}  is already in DB
# id:  {'5e52b889-f6ba-596b-97ef-eaa9df4f7224'}  is already in DB
# id:  {'7acfd74d-623e-590d-9546-83c7952555c7'}  is already in DB
# id:  {'13ad54ef-748a-56b5-abf8-ed60a8ec2d10'}  is already in DB
# id:  {'c0c289af-9a40-545a-bef6-6857794aed1a'}  is already in DB
# id:  {'31baa4bf-f19e-5bfd-8d22-05fc7cc6be5f'}  is already in DB
# id:  {'9ae64ae7-ebde-5ae1-aa05-52d2d17ac13b'}  is already in DB
# id:  {'def0658d-8435-5437-8239-b2f637370045'}  is already in DB
# id:  {'1d8b6455-ce84-576d-b346-0f095d1d171f'}  is already in DB
# id:  {'fa723e26-eebc-564c-a8ac-0f6a181b7a10'}  is already in DB
# id:  {'83e23582-128e-5307-a014-b7fe7154e68b'}  is already in DB
# id:  {'ef2d3069-ee67-5aaf-9101-3650c2ca583e'}  is already in DB
# id:  {'5114e184-b476-5b1e-9745-d514bf3c6cbf'}  is already in DB
# id:  {'533741be-8d16-5b4a-b052-fe497588968a'}  is already in DB
# id:  {'cf2632a7-c5a6-5e2c-9379-94da26c45954'}  is already in DB
# id:  {'c1a4181c-fa17-52a2-ad94-58aa235b41e5'}  is already in DB
# id:  {'b79b90da-63b3-5bb2-b706-3ff0309ade2b'}  is already in DB
# id:  {'a79aca46-1844-52d6-9efd-4dcd5de7fa79'}  is already in DB
# id:  {'f044b0de-2c92-515a-b9e7-65a6ddec9254'}  is already in DB
# id:  {'8aa58a0d-c6a8-569a-ba0b-55a46bfeb2b2'}  is already in DB
# id:  {'955056a2-2610-5d45-8f46-763c14883cd1'}  is already in DB
# id:  {'da14fc42-3694-5c54-b982-27fe5580e179'}  is already in DB
# id:  {'2968b436-4492-5211-b515-2680815174be'}  is already in DB
# id:  {'e01bb424-4b05-5f03-a2c1-f8a19ea67187'}  is already in DB
# id:  {'25302e5a-c0df-56fd-9fc1-948fd90b563a'}  is already in DB
# id:  {'f97bdda7-c378-50d9-a7c5-30ed161f94d1'}  is already in DB
# id:  {'cabd18b0-b4ad-50f8-8564-c2146f3d4296'}  is already in DB
# id:  {'113b1af1-8512-5522-9790-7ba659327cfe'}  is already in DB
# id:  {'41b1319e-c181-5785-be7a-adb79b9085c1'}  is already in DB
# id:  {'ea849b07-8e1a-5023-b6e1-2580e93e1ce8'}  is already in DB
# id:  {'4c7688a9-8339-54a7-a767-d0ca8487b6e3'}  is already in DB
# id:  {'9a3b1234-3f3d-5f4b-89f2-a7175eb3ac8e'}  is already in DB
# id:  {'5ec02fd0-1b28-59fa-aa67-4f40a632945f'}  is already in DB
# id:  {'4a2eea23-0a86-5b92-bde1-5b7a6f64d400'}  is already in DB
# id:  {'7936dee3-6efd-5b51-88c6-cb37827ea2e0'}  is already in DB
# id:  {'677ea87a-9ccd-591c-a54e-29c9c65ca6fb'}  is already in DB
# id:  {'41ea9260-01ce-5a74-a369-be8c15f47465'}  is already in DB
# id:  {'1b75379f-dd33-54f7-a712-8b5e8e53a098'}  is already in DB
# id:  {'c971c16e-0a1d-55c0-833c-f4478224ed0a'}  is already in DB
# id:  {'bd9929f0-bc3a-5fa4-8e70-347e0d1fb6b2'}  is already in DB
# id:  {'5eee4022-a319-5e55-8e61-6a9f5c930e40'}  is already in DB
# id:  {'a4e0b07f-7051-536e-9f45-61f3652815fa'}  is already in DB
# id:  {'06adbda8-7e19-5c93-934e-c97a619e7703'}  is already in DB
# id:  {'049091e7-f520-5fb4-8f48-2e5b93b628e6'}  is already in DB
# id:  {'56f0e4d6-a0b4-5575-a981-c0129ebf6905'}  is already in DB
# id:  {'a8febbc3-5057-5cd3-acda-6b4b469b424b'}  is already in DB
# id:  {'3a3b7665-35de-5e7e-8c26-83f5b7a2b22d'}  is already in DB
# id:  {'e8846c6a-3469-5c02-9f6a-149998d824bf'}  is already in DB
# id:  {'c136f84d-4cdc-5b7d-a00d-8ea555fb591d'}  is already in DB
# id:  {'a423abc6-2230-5242-a672-79c1899eb630'}  is already in DB
# id:  {'30f634e9-b75c-5b26-ba7a-e3bc7b38266e'}  is already in DB
# id:  {'1b738c88-81c5-5e9e-af3d-c810eb9dd75d'}  is already in DB
# id:  {'6fe0a243-5017-5157-b17d-d792fa8b39f7'}  is already in DB
# id:  {'be462442-79ee-5beb-af35-14b11a866c93'}  is already in DB
# id:  {'7bfa8814-fdde-528a-be05-96536a66ecc3'}  is already in DB
# id:  {'7ef03d9a-8106-56b3-b5b5-c95c92d968d9'}  is already in DB
# id:  {'2dd66dd0-4871-5124-87ff-d817ae5896b2'}  is already in DB
# id:  {'ac968a8c-a035-5c97-ad52-050fb56295de'}  is already in DB
# id:  {'ed1e447d-fe54-5e3f-9ad2-10356e2901ae'}  is already in DB
# id:  {'ac57ee90-6488-592c-a242-66fd0c511e8d'}  is already in DB
# id:  {'1a1dc0a8-28b6-57b5-935c-c09b3fedcfcc'}  is already in DB
# id:  {'35495227-f33e-5084-943a-68d861b21392'}  is already in DB
# id:  {'80a8ac0b-43f6-5db3-b698-f7278b9e217e'}  is already in DB
# id:  {'91a00bf1-e54d-5fec-9d2b-1f6a8720963b'}  is already in DB
# id:  {'d7065334-bbe3-5633-82d8-fc19d5fe7609'}  is already in DB
# id:  {'55af7a7f-f65f-5c4e-b12a-424c3c004253'}  is already in DB
# id:  {'3c432711-70dd-5630-a0f1-7c6bcd06e597'}  is already in DB
# id:  {'49bae005-a41e-545d-a5e1-41b5038fe7f6'}  is already in DB
# id:  {'3252f585-78c3-5330-be3a-791afec192ce'}  is already in DB
# id:  {'ee97e71a-04d2-5c95-8185-3da8900d0ddf'}  is already in DB
# id:  {'ac1ab41e-fad9-5808-8640-6f45a1c192a0'}  is already in DB
# id:  {'48c6fb11-9edc-55ff-9fe5-c4b2d8466283'}  is already in DB
# id:  {'52cf869f-1c62-5c95-bc6f-58fa06bdfa17'}  is already in DB
# id:  {'49578248-f6bd-567f-a5f3-8c71eda0e921'}  is already in DB
# id:  {'1c125184-2818-56d0-afa1-321488ec08a3'}  is already in DB
# id:  {'0e5afef9-87f1-5623-9c09-97c8af64b113'}  is already in DB
# id:  {'c0f6ed28-fc52-5bb9-bc49-2e9b0ddc483e'}  is already in DB
# id:  {'3a692902-2003-572e-b267-51f5cbe8e391'}  is already in DB
# id:  {'e8a449ce-9634-5eab-a7b9-dce48c35cf7a'}  is already in DB
# id:  {'31edf8e7-d2d7-5daf-89c0-ffbc8dd77765'}  is already in DB
# id:  {'9b95d97c-0c1f-5587-b40c-ffd8488bcf68'}  is already in DB
# id:  {'16f5c3e5-ae02-5f7c-a9e8-9ac68cf73965'}  is already in DB
# id:  {'359afd1d-df9e-5662-86d2-1c049918ef3f'}  is already in DB
# id:  {'3630a39b-04c8-5c3d-9fb0-0812e05758c0'}  is already in DB
# id:  {'93d282f1-8c5f-5477-a5a6-f9c23c7e6af8'}  is already in DB
# id:  {'b777aa50-15cb-51b3-ad1a-afd4624b544d'}  is already in DB
# id:  {'f7cb2372-6f81-5d22-bac6-ea7f81add5c1'}  is already in DB
# id:  {'be4daf32-1262-50f9-afde-fd0ba8b46b27'}  is already in DB
# id:  {'e2720051-4c07-5923-aeb1-f7b2606604fa'}  is already in DB
# id:  {'5c51d111-1eb7-5256-bea1-9ef48f7ff320'}  is already in DB
# id:  {'5a152049-6c00-51bb-9e76-5aff85a344ff'}  is already in DB
# id:  {'fe93fff5-f39f-55ba-ba44-8518d9670295'}  is already in DB
# id:  {'c8d8af16-88c5-5d12-ac26-ccbcfc40da51'}  is already in DB
# id:  {'b1cb1745-75fa-5677-a414-0b18ee3bab47'}  is already in DB
# id:  {'08fb4b75-deb0-5139-8617-1f42326050ce'}  is already in DB
# id:  {'2a6118cd-9cb1-5673-8bb0-8ab712db3a54'}  is already in DB
# id:  {'2adfacb6-729c-579f-829d-dfab2cdfbd5c'}  is already in DB
# id:  {'f763ea60-0b9b-51e8-86e1-9ae35948f721'}  is already in DB
# id:  {'76f064e4-3485-5aea-8362-3a1408f0ff5a'}  is already in DB
# id:  {'c1623039-f59b-5ca3-95a5-cc9a0f40934e'}  is already in DB
# id:  {'3d0e07ad-e139-567e-b4a3-281fe82ca166'}  is already in DB
# id:  {'35a4fbb7-a2fe-5a34-854d-b3910a51a0d9'}  is already in DB
# id:  {'81bff21f-ad02-5885-b3cf-30578660d196'}  is already in DB
# id:  {'0d0e040e-ab81-591f-9c12-8a6d3e95a634'}  is already in DB
# id:  {'c4078f2e-9e46-5b32-8783-386cdc3faa05'}  is already in DB
# id:  {'0b64c23d-0829-527f-aefe-f8297d6e8e37'}  is already in DB
# id:  {'091e880c-77e6-512d-a23c-a2a43e66c1dc'}  is already in DB
# id:  {'2517666d-41a0-517b-88b5-1f62f82c2cfd'}  is already in DB
# id:  {'f75edfc0-1a20-5ab7-b35d-78c74d38d791'}  is already in DB
# id:  {'62a3767a-d3d0-5d95-92e6-58c854222a98'}  is already in DB
# id:  {'2bbe18bd-9c06-54f8-9d48-1c50237f3384'}  is already in DB
# id:  {'5dc74f3e-451a-5fb2-9609-29aaa0ce2823'}  is already in DB
# id:  {'7b838c1b-b8bd-5de5-bb73-33e585e122d8'}  is already in DB
# id:  {'d0bb9fbe-29e5-538a-96fa-420497f13d60'}  is already in DB
# id:  {'714cac7f-10aa-5292-8721-00179726940b'}  is already in DB
# id:  {'da294671-9957-5688-b1cb-3d2ba943c4a5'}  is already in DB
# id:  {'3142dea9-c864-5a2f-9da4-58be2e68bfd0'}  is already in DB
# id:  {'06706909-23b2-5fb7-9b8b-6786b5fb7379'}  is already in DB
# id:  {'37b66445-6241-53bd-b1af-a1114f6abb92'}  is already in DB
# id:  {'2c0c4ecb-e55b-528f-883e-b8857cd58e7e'}  is already in DB
# id:  {'80cba2b7-534a-5bc7-a712-8f071cc5a0ff'}  is already in DB
# id:  {'4f029a7c-43d8-53e3-8ee9-02e7be836744'}  is already in DB
# id:  {'d9e126b3-cb6f-5f5a-b49e-35c80f08e369'}  is already in DB
# id:  {'56f0d495-55f6-5331-8232-036d50ffe23a'}  is already in DB
# id:  {'e6c6f415-d17d-5006-9ca2-5768cd68539c'}  is already in DB
# id:  {'fe769738-6343-5535-a8af-c5e0b4f78bf8'}  is already in DB
# id:  {'4d74ac85-fa67-5095-b03d-19b022c70e3a'}  is already in DB
# id:  {'a2a65b25-1130-51a1-a261-27e77ac6dada'}  is already in DB
# id:  {'f4dbe8ec-1d99-5995-956a-fb8f18fd8ee9'}  is already in DB
# id:  {'f45b7295-e021-547f-9556-df4a5ccbf93a'}  is already in DB
# id:  {'21859ec0-280a-520a-836a-871e41a89e73'}  is already in DB
# id:  {'6ea39af0-a588-54ea-b856-3f7908c44c97'}  is already in DB
# id:  {'b563e46b-4fa8-50a8-8e45-cf0aa88f1653'}  is already in DB
# id:  {'eb8e74db-0a8a-536e-9421-3a0d0befae3e'}  is already in DB
# id:  {'18318555-4f21-5880-a9eb-3fea2a569fb5'}  is already in DB
# id:  {'fdab9435-b69a-5298-a394-d10ca4899135'}  is already in DB
# id:  {'aaa75a7b-d83e-598c-a07b-dcbe2ced8745'}  is already in DB
# id:  {'7c0fe519-14bb-5a8f-81a7-da5b0cbae4c9'}  is already in DB
# id:  {'ada55034-8801-5d27-80fd-993b3fe81973'}  is already in DB
# id:  {'bfca0fa0-324f-5072-820e-1298f4317db4'}  is already in DB
# id:  {'f310479d-b5da-5097-bb64-38fabf2237ef'}  is already in DB
# id:  {'945c411e-f617-5197-bae4-953a86e833c7'}  is already in DB
# id:  {'d69bd576-df0b-53b6-802e-25a6aa23c189'}  is already in DB
# id:  {'54124291-3666-5d69-8875-61b75715e4de'}  is already in DB
# id:  {'8b3b8c86-1b03-5c99-9e79-53309c38ad77'}  is already in DB
# id:  {'c298079a-e8e1-5622-ba02-73a5a720bc79'}  is already in DB
# id:  {'e40ee90b-975c-5244-900f-219888f6df2f'}  is already in DB
# id:  {'7713203b-95e6-5303-b2f5-2598826fd5ae'}  is already in DB
# id:  {'27785e87-32cb-5ff1-a487-449e3c0a1b2a'}  is already in DB
# id:  {'e4d0fcb5-c056-555a-b518-c95f986048e1'}  is already in DB
# id:  {'9ad3f3d7-c71c-58b6-89d0-f5e97547d897'}  is already in DB
# id:  {'7672b739-e418-5c4b-a6cb-d09d6a2dd6e1'}  is already in DB
# id:  {'970e73b8-6ae7-5985-83e0-02fe8436f2ff'}  is already in DB
# id:  {'4298f37b-881b-54f0-867f-555d7164ca54'}  is already in DB
# id:  {'63b0ef95-98ab-5865-a98a-850fd5fcf60d'}  is already in DB
# id:  {'d2a97756-0d97-59e7-93bf-bc0177929399'}  is already in DB
# id:  {'5facdfea-245f-5dd2-a075-2a7a6e7b6434'}  is already in DB
# id:  {'6a2cd05c-a847-5d67-8a6a-22508a3a8ac2'}  is already in DB
# id:  {'8101de85-335e-5581-b2be-4578e5901627'}  is already in DB
# id:  {'318270c0-615f-515e-85e9-2a0ee446d79f'}  is already in DB
# id:  {'daebc7ab-ee5c-55ec-96c5-55c83a523513'}  is already in DB
# id:  {'9c7a5b9d-25b1-521b-9722-f84291ea3022'}  is already in DB
# id:  {'27ba21d3-06a3-543b-93cc-c77f34576013'}  is already in DB
# id:  {'cc42c1ef-79c7-5719-ab6e-064c4200c6d3'}  is already in DB
# id:  {'82d0a5ac-bc5b-5ae8-a429-6757692c0273'}  is already in DB
# id:  {'dcecca54-56d9-5e23-8962-6fb7040df692'}  is already in DB
# id:  {'9c421308-6d0a-53f2-a943-dbfe929b9113'}  is already in DB
# id:  {'b30e6005-6fb9-580a-ad11-975afacd90f0'}  is already in DB
# id:  {'f9ae7a3e-44d3-5f8e-bae0-574fab099fe1'}  is already in DB
# id:  {'5cc073a3-8873-596d-ab29-f5234306f040'}  is already in DB
# id:  {'5db44f48-fcaa-53eb-9920-df27eef3a753'}  is already in DB
# id:  {'66d29680-fb72-5427-8062-bd5ca400fee9'}  is already in DB
# id:  {'2f41795c-ed4b-50f4-accf-322e621dbfdb'}  is already in DB
# id:  {'df23d0a7-a301-5ecd-b3ad-59c13cacb96e'}  is already in DB
# id:  {'cb80f571-da72-510d-ba07-1cbf4cea1ce8'}  is already in DB
# id:  {'8178c4bc-a927-5164-8766-819078deb829'}  is already in DB
# id:  {'1abb2f0e-6469-5ad6-9d5f-3a550c446e31'}  is already in DB
# id:  {'200529af-bb0e-5e72-a776-35c169955740'}  is already in DB
# id:  {'ed66aa74-dcfe-5ab4-9aae-d893b938a358'}  is already in DB
# id:  {'55177170-a21e-595e-a80c-53bb936e2d60'}  is already in DB
# id:  {'572fabe1-eb7f-5907-9884-91802559a233'}  is already in DB
# id:  {'6e79dfb8-e3af-5c1c-9067-a66eef796a93'}  is already in DB
# id:  {'458fe261-3735-5a5e-bd3a-de21bf4f6054'}  is already in DB
# id:  {'c2a89ed0-4bc0-5a52-ab78-d26ec397daa0'}  is already in DB
# id:  {'3ab793e8-16fd-5daf-b836-093399149cb1'}  is already in DB
# id:  {'51cc5332-427c-59fa-a804-4ec1bcb68f1b'}  is already in DB
# id:  {'abe2c196-2139-5828-9d38-adfce16a9aec'}  is already in DB
# id:  {'3ce1bd53-70cd-50e6-88fb-a23e2b104abc'}  is already in DB
# id:  {'6182cef4-1c23-5704-afab-a9ae51f2b45c'}  is already in DB
# id:  {'239ad723-030f-5636-aeef-bd76f91b8bcd'}  is already in DB
# id:  {'41b02510-0f62-5543-98b7-ceaffdf7a0a4'}  is already in DB
# id:  {'7b920086-4014-57ba-aaa2-1366450435c5'}  is already in DB
# id:  {'b8058119-6a46-5721-909f-cdc1f3d3a7bb'}  is already in DB
# id:  {'83313817-9cd0-594d-9202-83014eb3c167'}  is already in DB
# id:  {'568710e2-f3ef-5008-8479-9c096bb7cdbd'}  is already in DB
# id:  {'a70b1dd2-ea0a-55ec-8b23-c76a1c30ebe7'}  is already in DB
# id:  {'73cf9cef-e5de-51f3-bf6c-2366a38df8bf'}  is already in DB
# id:  {'b70a42e6-57a1-5825-b5fc-fba94e55e033'}  is already in DB
# id:  {'c5abdd0d-2209-5e86-a924-34e303f69ef2'}  is already in DB
# id:  {'7de3f2a8-15c4-5583-ac87-627964b810e7'}  is already in DB
# id:  {'4c9ace75-a56b-5b6c-8811-616483f9e9b3'}  is already in DB
# id:  {'6b5f77f9-54b2-5120-b694-b05b550b6eb8'}  is already in DB
# id:  {'53faddf6-d55b-550e-a3df-39132a4e048c'}  is already in DB
# id:  {'6f197a2e-a32a-5f2e-a451-ca3c577f8ae7'}  is already in DB
# id:  {'f60205ea-cb96-59d9-bcb8-5541e908b433'}  is already in DB
# id:  {'6828a376-c95b-56fa-ae3b-fd316a9551a1'}  is already in DB
# id:  {'f227ac19-ded3-5260-8034-ac3231e9ba11'}  is already in DB
# id:  {'2e7a1f05-86c5-54bc-b5f4-f4f78fc42896'}  is already in DB
# id:  {'51705e11-5026-5321-8cd3-585898ab3f27'}  is already in DB
# id:  {'59abd575-d890-592a-aa42-3777845edd8f'}  is already in DB
# id:  {'64f42b1e-0b94-5d5a-a8f8-704a3644efee'}  is already in DB
# id:  {'54b3c9d2-e5a1-5395-b12e-d2949e0fc874'}  is already in DB
# id:  {'0e139688-0ae0-55ee-a58a-7be0ecfd5137'}  is already in DB
# id:  {'d8bf1b8a-d99a-5396-b3e6-9ff34da82e92'}  is already in DB
# id:  {'43d16dd5-daad-5100-9435-29a665febafa'}  is already in DB
# id:  {'f51f3b25-6b0c-5356-a291-a0669dd89aa2'}  is already in DB
# id:  {'1ed291bb-0747-543b-a475-7497e0c5c554'}  is already in DB
# id:  {'9cee9959-d3f6-5ecc-9638-060114f7751c'}  is already in DB
# id:  {'5997b271-67ef-5c23-ad61-5e1a9573d605'}  is already in DB
# id:  {'6cec5642-defe-59fa-a8e5-e25ccc6ebca1'}  is already in DB
# id:  {'58cae201-cbba-54f7-bdec-6a2c7486c9fc'}  is already in DB
# id:  {'e7e8e58f-b8a8-5ee4-b228-4e14eb123340'}  is already in DB
# id:  {'b324db06-b495-5579-8c2e-6b4cd2be39ba'}  is already in DB
# id:  {'9ecf2d0f-08c4-5857-9050-bf8af184532b'}  is already in DB
# id:  {'70cf55f2-05bd-5b74-bc77-7b315223256f'}  is already in DB
# id:  {'60025c81-5d53-507c-8c30-159f053502cd'}  is already in DB
# id:  {'2c418f1f-cf3d-52c8-8773-23083efc34c9'}  is already in DB
# id:  {'45714456-ac56-5268-a5a4-686032f774de'}  is already in DB
# id:  {'9894be56-16d0-547d-b235-b7cf20bd3649'}  is already in DB
# id:  {'22440780-0fea-5ddb-b160-f059b3d8683a'}  is already in DB
# id:  {'b2c33c1e-3352-57ed-a741-8479e0f11558'}  is already in DB
# id:  {'2d81468f-d4db-57e0-bb9c-98d5ebadafcf'}  is already in DB
# id:  {'b64d9a58-c57a-5b56-9515-6451a73136ac'}  is already in DB
# id:  {'456b3384-0187-56d1-8187-be1d4cf2a0bb'}  is already in DB
# id:  {'c57410a9-25c7-5ec7-90e1-7c4d2cdc8427'}  is already in DB
# id:  {'585bbdc4-e29b-5232-8dec-d7f0117feaf3'}  is already in DB
# id:  {'1f944e29-0646-58c3-8523-525ab40e86af'}  is already in DB
# id:  {'70cefdb1-aae9-5014-8bec-f518a17471dc'}  is already in DB
# id:  {'eeb622c0-d06f-5b65-998d-83e4ef7a3742'}  is already in DB
# id:  {'32fbcc5a-7461-554b-b5ff-6635243db441'}  is already in DB
# id:  {'dad023e0-2e6d-575a-95d9-0bfdf5038d7f'}  is already in DB
# id:  {'413b6c67-8020-5eb8-b4bd-a07a9b3edaee'}  is already in DB
# id:  {'b9fa7eea-691e-59a8-8917-9ae53121d6a6'}  is already in DB
# id:  {'a3af3c42-ca00-5f6b-8296-d345a62844c5'}  is already in DB
# id:  {'30e7d512-3923-51bd-9076-783513ac73fc'}  is already in DB
# id:  {'60097a7f-1e11-5f4b-9056-e4aa7d05b5a4'}  is already in DB
# id:  {'b3d309fd-182c-5279-bbed-1bfac69b6ff7'}  is already in DB
# id:  {'4a8ba1bc-c8f9-5b86-882d-3fd9a7d10a3c'}  is already in DB
# id:  {'cf93e012-4fdd-5d73-8220-466084e0d6d6'}  is already in DB
# id:  {'0382d72c-efba-5b01-9623-bf72c834b159'}  is already in DB
# id:  {'2f7e8ce7-50b8-5e24-811a-696d1fd24e10'}  is already in DB
# id:  {'3c329844-7218-50e0-948c-3282299857bc'}  is already in DB
# id:  {'1cb0eb20-608f-5a33-81e6-84bc91dd928a'}  is already in DB
# id:  {'ddde2c73-dfc7-5569-8dd0-944dd9ed4f40'}  is already in DB
# id:  {'a9dcc79f-2218-5538-8fca-f82aa7b1a73c'}  is already in DB
# id:  {'9ad26035-a5c9-5a05-80d4-73495bfe5c27'}  is already in DB
# id:  {'3a7185d8-82cf-54a1-9e0d-3d98cb434463'}  is already in DB
# id:  {'b2a23721-0556-5d00-9434-da949658373c'}  is already in DB
# id:  {'903a0c56-26a8-50a8-92e3-c23abb43d444'}  is already in DB
# id:  {'ec561bd7-efe9-5c46-aeb6-7f0b8daa6864'}  is already in DB
# id:  {'0802a312-2a2a-53a8-b7db-acf65a068f23'}  is already in DB
# id:  {'f2c23cae-62a6-5c84-9bfb-8a288752ea4d'}  is already in DB
# id:  {'572f6606-ed97-506e-a45a-6a2c2577e583'}  is already in DB
# id:  {'d587d8e8-beff-5713-ba61-a1336e426d42'}  is already in DB
# id:  {'5fafeab8-15d2-5041-9763-79cf5a42b58b'}  is already in DB
# id:  {'de7a16e6-cff8-5b3c-b127-8b936bc60275'}  is already in DB
# id:  {'238ecf35-9cd6-5545-bfa7-db4e168f4f99'}  is already in DB
# id:  {'b2e003d0-6b0f-56cc-b5d2-d220a494dfa3'}  is already in DB
# id:  {'36271020-9d80-55dd-9572-ca41db73990e'}  is already in DB
# id:  {'c4124986-aab7-5d67-9d51-6d8969e26a9d'}  is already in DB
# id:  {'b9bb84b8-5f38-5d6d-bca3-667f383c7aae'}  is already in DB
# id:  {'2b110111-e62a-5c8e-a965-89a8d7f82828'}  is already in DB
# id:  {'afd4fbfc-3968-5ec0-86fe-4001844a3419'}  is already in DB
# id:  {'51623746-5015-5c06-ab55-62d20715c7c3'}  is already in DB
# id:  {'1f41d8cf-b042-59ad-bd55-c25a98a9fffc'}  is already in DB
# id:  {'fcd90634-333e-5736-b0d0-c1864861a539'}  is already in DB
# id:  {'f8145ff9-f1eb-5995-b26f-8f2e3f6b23a5'}  is already in DB
# id:  {'358e1997-4a63-5268-900c-21837e7bde66'}  is already in DB
# id:  {'31b5484e-0d94-5041-905b-ba85bfe5eded'}  is already in DB
# id:  {'fcb3cb5b-31b6-5f15-be53-35ed1679aa57'}  is already in DB
# id:  {'08eab978-fb3e-5462-b580-bc6a9b7f1fd7'}  is already in DB
# id:  {'66cf9ca5-e362-545e-b0c3-1eebbaf75a84'}  is already in DB
# id:  {'fd8c090c-40ff-57f3-ade8-e315eae6980e'}  is already in DB
# id:  {'beafb3d5-0520-5737-9126-215340b3b28f'}  is already in DB
# id:  {'8fe5df1c-12e2-5400-bbf8-0bba27862939'}  is already in DB
# id:  {'4c018a2b-d7d8-5a2a-8f8e-e48205b75af6'}  is already in DB
# id:  {'7f5bdc92-2ccb-5461-8e5d-b3d1c08eca86'}  is already in DB
# id:  {'365d9c60-5779-537c-8cc0-dfa71c19423c'}  is already in DB
# id:  {'05b57150-ee5f-530b-af6f-292c1b996741'}  is already in DB
# id:  {'433d5f35-60ab-5e8a-a8eb-bdd9a9f4ffbf'}  is already in DB
# id:  {'008e0a47-47c4-5d48-a570-d421c0cc6573'}  is already in DB
# id:  {'3f2a0ac0-d907-521a-b253-a8cd03dc6526'}  is already in DB
# id:  {'96118462-9e94-5709-910f-34eeb1f09fdd'}  is already in DB
# id:  {'17c9d081-95da-5378-a26b-cb7cca9168bc'}  is already in DB
# id:  {'a7d65ba3-01ed-503d-b89b-002153b2ceec'}  is already in DB
# id:  {'170e896b-e181-5885-b7ab-ba9de043dd61'}  is already in DB
# id:  {'a4cf2a9b-e5ba-57c8-bc76-5c8623810553'}  is already in DB
# id:  {'4b4e8005-9554-5788-ad46-a94e380a180d'}  is already in DB
# id:  {'e948ebd5-6a5e-5503-8e80-1fe60f505ab3'}  is already in DB
# id:  {'c410acf3-8411-5731-9990-231caa0708fc'}  is already in DB
# id:  {'b51e0d89-f334-5d38-abed-199ab1aece4c'}  is already in DB
# id:  {'33937779-77a9-5429-9b11-9531805cb16c'}  is already in DB
# id:  {'a97b5518-e0ac-5602-9f53-73035ab95fff'}  is already in DB
# id:  {'09c3ca79-fab8-5b3c-947a-8219da272ac3'}  is already in DB
# id:  {'b96b407c-4be9-5aff-9f47-885844107a50'}  is already in DB
# id:  {'67854729-6466-5683-bdcf-8cfb8b3bd0d3'}  is already in DB
# id:  {'c1b21e0f-c114-5749-bb32-6a4b304c7424'}  is already in DB
# id:  {'902dec57-b8c1-572f-8e30-16a331fa4907'}  is already in DB
# id:  {'885b6fe2-10eb-568d-bc63-84fede01574d'}  is already in DB
# id:  {'dba114b3-6a58-5e70-8d73-50a35f7cb721'}  is already in DB
# id:  {'7961af40-958e-568c-9d73-3e75fa90b83a'}  is already in DB
# id:  {'b6d08d7e-c4f3-5562-aeb5-410d5c686de7'}  is already in DB
# id:  {'8b317f88-a7bb-57a2-b56a-dc349ffd03a5'}  is already in DB
# id:  {'e6882cc7-da86-500e-8a24-cc7bc9f7c42b'}  is already in DB
# id:  {'f11fe7a9-1da2-5bb9-b9de-f12e268bf6dd'}  is already in DB
# id:  {'54ca77a5-679d-5180-9124-eb0b94081e4f'}  is already in DB
# id:  {'8a48f9e4-90ca-5f02-acd9-92c98c158e06'}  is already in DB
# id:  {'a7ec9651-2e62-589d-abaa-22fc783a9d2f'}  is already in DB
# id:  {'e5c8fb01-ede6-5618-8921-1db4ca11ff7d'}  is already in DB
# id:  {'2ef00eaa-a04f-5b39-9a12-de81a8659154'}  is already in DB
# id:  {'dd3c84d2-91b8-51f3-8489-0eb45f153fd8'}  is already in DB
# id:  {'5525717f-0aa7-5f72-8c3b-763fb211ec55'}  is already in DB
# id:  {'77090986-a3f0-55f0-9ed0-9a8607cfd83c'}  is already in DB
# id:  {'d84b02e0-3ce7-5e27-9e34-993f5cce0dc0'}  is already in DB
# id:  {'8b22fcb2-53e2-5633-9c3b-ff6ba47ccb86'}  is already in DB
# id:  {'64cc6eae-79ca-5658-a58f-86b8672cfec4'}  is already in DB
# id:  {'e991a8b2-af99-58d0-b394-366fe83e1c38'}  is already in DB
# id:  {'f0d53311-2ec5-5ad7-b82b-67f8f05800ec'}  is already in DB
# id:  {'7e98ba0f-90e4-587a-a62a-3b47973bbd6b'}  is already in DB
# id:  {'5ebfc979-8e10-5aa8-9fe4-96a9fb9f89b4'}  is already in DB
# id:  {'1e3c523c-89e5-5a43-8eae-e7ff8a4ba5be'}  is already in DB
# id:  {'d95548d0-1ba3-562f-bd4f-5c1dc1899735'}  is already in DB
# id:  {'4219f8a4-c854-5f71-962d-6758ae68fe33'}  is already in DB
# id:  {'362e8a3d-cd6c-57cf-96f0-9a7c445b7c20'}  is already in DB
# id:  {'1fd5187d-353a-5c07-8ee2-9cee2f849ea6'}  is already in DB
# id:  {'25e2d036-78ba-5bfc-9701-3a797df7addc'}  is already in DB
# id:  {'303f09f1-d73c-5179-a1b7-fb8c2950f7d8'}  is already in DB
# id:  {'e87c8849-788c-5b56-8105-0a282e1625d5'}  is already in DB
# id:  {'60efb3f9-ad09-5c31-be86-a89434bbcad7'}  is already in DB
# id:  {'6742b20e-622f-5343-958e-f5032a36fb6a'}  is already in DB
# id:  {'32fefd0c-e031-5041-bbb9-094b5a7e26eb'}  is already in DB
# id:  {'2edd1231-da1b-5933-89f2-3c7100a35aa0'}  is already in DB
# id:  {'d19d6fbd-0c57-58ac-86d3-52884a305e1d'}  is already in DB
# id:  {'34be878b-1dc2-50d1-9700-fa8f304458c2'}  is already in DB
# id:  {'0091c879-daab-5470-8a6e-c6965eaba9b5'}  is already in DB
# id:  {'e5d71c5f-62f2-5892-b7d3-6b7e6fd4b385'}  is already in DB
# id:  {'25813015-57f7-5f66-931c-9cf01511be68'}  is already in DB
# id:  {'72f822b6-630a-59dd-8ce1-1dd971e6a09a'}  is already in DB
# id:  {'04ea4cce-798f-5d1d-a124-f891a3d3f705'}  is already in DB
# id:  {'4908081e-a821-551c-809c-9c0979acb8af'}  is already in DB
# id:  {'a32d92cd-efd4-54eb-9f48-cc85a69fb157'}  is already in DB
# id:  {'e51f1ea7-1001-5567-a13e-e150334e65a9'}  is already in DB
# id:  {'e103b194-f8fd-5e88-8a74-b0f9609d8fc4'}  is already in DB
# id:  {'d1fc6067-ad7d-5d45-a047-ff8ffa9093a8'}  is already in DB
# id:  {'a6ae0eec-008f-5948-957b-e563e497ea42'}  is already in DB
# id:  {'e301af94-08d6-5b6e-9fd1-6e2414ca2d07'}  is already in DB
# id:  {'3f755f63-4e63-531d-8e36-155ac0075fbb'}  is already in DB
# id:  {'c56cf35b-60f7-5b31-8c63-f10f6736e732'}  is already in DB
# id:  {'89148c04-cce0-53bb-86f8-5d484c32c095'}  is already in DB
# id:  {'851e8a25-9b80-5b0b-b4dd-3e26e04e40a6'}  is already in DB
# id:  {'bbf77322-4946-5943-88bc-01b7e6b331db'}  is already in DB
# id:  {'0b9f3dc5-ab65-5259-9f69-7fe59bac0e1d'}  is already in DB
# id:  {'e47d3929-87d4-55e0-915f-9c058c47bc5d'}  is already in DB
# id:  {'59917e80-60c7-5ad8-b49c-1a2c95d99ff3'}  is already in DB
# id:  {'69cadb0f-54c1-58cf-80d8-225d0a8af51f'}  is already in DB
# id:  {'d727d4ce-7dbd-5acd-b4ba-a77360f2c540'}  is already in DB
# id:  {'7287eaa7-fd6c-5ee0-9e92-7ef9bddc76a5'}  is already in DB
# id:  {'695ba0d5-b697-55c1-8374-c351649b1c16'}  is already in DB
# id:  {'bcbb8f93-7585-5bfa-9d78-7f6014940fe2'}  is already in DB
# id:  {'b4e29a53-379b-5274-a732-5883ea4f19a8'}  is already in DB
# id:  {'c3ed7191-f9c1-56a1-bee1-72781171d26a'}  is already in DB
# id:  {'3977a9b8-e6ef-555d-a3b9-34635fc93961'}  is already in DB
# id:  {'f1ee8970-f7d6-5de0-b6c7-7bd18734d167'}  is already in DB
# id:  {'a0437817-f724-50b4-a715-c7dfb8c16f47'}  is already in DB
# id:  {'6f2487fc-2470-5f59-9a2f-dd9e249d217c'}  is already in DB
# id:  {'19c1a9bd-7e85-5631-a3ca-9407041cc454'}  is already in DB
# id:  {'5254e7c7-778d-5409-8e77-ec1894beadfb'}  is already in DB
# id:  {'5e44748b-ffc5-559b-a6d5-345fa51339e4'}  is already in DB
# id:  {'88f3c6d5-12f5-58b8-a651-3846718961f7'}  is already in DB
# id:  {'390cce31-1faa-50c4-a37d-00e8358a133b'}  is already in DB
# id:  {'6d66d801-8f24-5dcf-a257-ae65110f3181'}  is already in DB
# id:  {'f3672174-ba2a-56bc-9b9d-bfa81cd44ffa'}  is already in DB
# id:  {'a417b357-83f9-516f-bba2-94440bee45ec'}  is already in DB
# id:  {'e826b6c3-1749-5eb5-9bec-c21aa30ad2ab'}  is already in DB
# id:  {'4d330d85-06b9-5a38-badb-bc936ad326db'}  is already in DB
# id:  {'09881dcc-30b6-5a6e-bc46-34449d866ced'}  is already in DB
# id:  {'5ff42ba0-8eee-501f-837c-e39f8078351a'}  is already in DB
# id:  {'851db9a9-0038-53cf-9f97-b060eab5fd9a'}  is already in DB
# id:  {'7350a08c-5624-5964-87a4-9ff1993db071'}  is already in DB
# id:  {'2737f8e0-9f7e-51fb-b63b-5967efa723d6'}  is already in DB
# id:  {'8ccde1c1-5e17-59c3-9302-2ea753ae75bd'}  is already in DB
# id:  {'5e00f422-43ca-5cda-aa50-b78133ae7166'}  is already in DB
# id:  {'ffe047da-5fef-5e98-a841-ba71041c56f4'}  is already in DB
# id:  {'ae11ac8d-2343-5b06-b883-6faaea2748e0'}  is already in DB
# id:  {'a1a4e6fb-0d55-5ff9-b505-00cb3e3033e0'}  is already in DB
# id:  {'919797d7-428f-54aa-875c-ccb32080697b'}  is already in DB
# id:  {'472ae1c8-e9ab-51d2-82b3-d109806297a8'}  is already in DB
# id:  {'300f42ea-5e04-587d-828d-e9ae78ea8c8d'}  is already in DB
# id:  {'5c0fa3a9-18c3-5245-a8b1-e15e674186e7'}  is already in DB
# id:  {'23ca5d61-8c11-53cc-a57e-3a7695d4a3f7'}  is already in DB
# id:  {'ab17d4ac-7015-51e3-bb0c-e7dea48acb7a'}  is already in DB
# id:  {'73c2fd4d-43d5-5a08-9c6c-bf6cb4edbcc5'}  is already in DB
# id:  {'45b6374b-e5f2-587e-946b-30b1fcc9964f'}  is already in DB
# id:  {'18e91ed3-a796-5ec4-9f5e-c47275531d56'}  is already in DB
# id:  {'b090d807-6f25-543c-8ef3-7d02e5873b81'}  is already in DB
# id:  {'e2d7e60b-1519-538c-b51a-a2a5499a2743'}  is already in DB
# id:  {'23e3289f-b22f-5fad-ba89-537a1f9716b7'}  is already in DB
# id:  {'3f574c42-0c3c-58b8-94c9-089957e91781'}  is already in DB
# id:  {'9376a11b-75b7-58a0-92eb-63b5210527e6'}  is already in DB
# id:  {'d09d7aeb-fa00-5778-a13d-8b4e4548a92c'}  is already in DB
# id:  {'600c4334-c03a-5de4-9e52-ea983ab88c51'}  is already in DB
# id:  {'cf32c28c-9aa9-54ce-a6e2-28ce3a8c796f'}  is already in DB
# id:  {'e6064cb2-bbd1-5252-a3ef-c53ee4d7e330'}  is already in DB
# id:  {'17693baa-40a9-572b-bc2e-a3eaf1a10bad'}  is already in DB
# id:  {'5585b5b6-9b2a-52aa-bd60-22aaa5fd3864'}  is already in DB
# id:  {'69ff35c7-8402-5720-8067-34514ef35ae3'}  is already in DB
# id:  {'9c79da8a-e986-52ea-a354-c245a2771aae'}  is already in DB
# id:  {'7f3dbe5d-3c58-5a33-b1ce-2ae146f05bec'}  is already in DB
# id:  {'7044f866-7af0-5859-8607-9d7ac0daf27b'}  is already in DB
# id:  {'56a6cda8-30da-5903-b106-02ef3eb0e247'}  is already in DB
# id:  {'f8c44ae3-5afc-527b-b169-921939273520'}  is already in DB
# id:  {'c1f3d208-0e75-56e7-99b9-cb1d01c2fdbc'}  is already in DB
# id:  {'67b4165f-19bc-54f1-9581-231ffc092c0f'}  is already in DB
# id:  {'6aa58941-76c9-518a-b49f-a63f2fd286fe'}  is already in DB
# id:  {'9e6e4ec6-ca65-532b-9cbd-6b6d0a2b6325'}  is already in DB
# id:  {'c6799158-4332-5b17-9f8a-da3e9cb8d649'}  is already in DB
# id:  {'618b1fbc-d0df-50f4-9819-04d088f600cf'}  is already in DB
# id:  {'b87d1340-61a7-53b4-9e3c-fcc0b6860691'}  is already in DB
# id:  {'248d9bc2-00a1-5129-9ea6-e90bc107d76c'}  is already in DB
# id:  {'77d2de79-c832-5c9e-96b0-3e1f9a69248f'}  is already in DB
# id:  {'46902762-80b4-5e15-b05b-3c1fc38b72a3'}  is already in DB
# id:  {'a3ae8e6b-878d-5af9-bf45-4c95a7d288a0'}  is already in DB
# id:  {'8efdbb99-bf25-5933-a0af-52eff8413d0d'}  is already in DB
# id:  {'f5c4c6a5-7d66-5b23-851d-e3d56e1fcf47'}  is already in DB
# id:  {'d8805d84-dfe2-5a6b-b6fa-99d90aa344ce'}  is already in DB
# id:  {'bc76f040-c3c4-527c-842e-4fc82c3e9a40'}  is already in DB
# id:  {'3c13ae48-0965-52fc-a109-e54fa0415489'}  is already in DB
# id:  {'3debbc23-bd5b-58ba-9bab-b838717feb34'}  is already in DB
# id:  {'dd10791f-7f03-50c9-9fb5-c9c4958ae042'}  is already in DB
# id:  {'a9f76c0b-1375-587a-8e4d-a0595d40286b'}  is already in DB
# id:  {'e09931dd-5341-55f4-8080-5be6d813b58b'}  is already in DB
# id:  {'6ac115d1-12c0-5fea-82a7-659ae5596c16'}  is already in DB
# id:  {'64ecbc8d-ed09-536a-9f61-c2b942ecfec5'}  is already in DB
# id:  {'3f6194a7-daa8-5904-96e0-1d77f44d780b'}  is already in DB
# id:  {'bbf3cbcf-80b1-5c00-bd8b-9dad9fcc7558'}  is already in DB
# id:  {'17d8c7bf-e4a4-57ea-885f-ee1e7fe60333'}  is already in DB
# id:  {'5ec137fb-f867-5fb5-8d4f-1705153471f4'}  is already in DB
# id:  {'4a6ecea0-c3ca-591c-a68f-8cd70a06d631'}  is already in DB
# id:  {'60f21f69-e323-52d8-92fd-4dc33ad7f832'}  is already in DB
# id:  {'04ff9deb-4084-5da6-bd7d-f84a7815dd65'}  is already in DB
# id:  {'cc9245f0-fd8f-5d09-af1f-b2ab24d4c737'}  is already in DB
# id:  {'1e7e610f-afb2-54ec-b9b4-839a5966ce06'}  is already in DB
# id:  {'1880d597-2950-54de-a6e9-7f5caf072225'}  is already in DB
# id:  {'7c445c8c-2d18-5b4b-9c2d-0a5caed1cb56'}  is already in DB
# id:  {'01e71b8b-959c-5b77-88fa-e8b326d5f021'}  is already in DB
# id:  {'5da1ad27-cd51-5ccb-bc99-b0aa1677cdb5'}  is already in DB
# id:  {'e170cd85-43e4-567a-bb94-f18f9df2b299'}  is already in DB
# id:  {'0d9c724c-b761-5d73-aa57-4be9b3055af2'}  is already in DB
# id:  {'5c33daff-0444-5422-a1f0-dc09b826d87a'}  is already in DB
# id:  {'129c3548-f71c-5a49-a751-13a4cac8c7e3'}  is already in DB
# id:  {'73282649-e46c-5de6-bd74-9ff075f59b3b'}  is already in DB
# id:  {'8d795355-9689-5beb-9a88-06c5653f78c0'}  is already in DB
# id:  {'76c15d42-3260-5c08-951e-6f1dc11025c2'}  is already in DB
# id:  {'bc8e3480-5073-5b78-9ebb-d79f12dd41a8'}  is already in DB
# id:  {'42de4744-94e8-5731-ba71-41aefec59bc6'}  is already in DB
# id:  {'d3f6fc13-a8f7-5237-a6b9-fdec36b106f1'}  is already in DB
# id:  {'a7a0d8b7-2663-5c91-bed5-329d1fc0a293'}  is already in DB
# id:  {'1edd3b60-8247-59fc-8509-825bb90298ee'}  is already in DB
# id:  {'60d70b8d-5952-510e-b424-a163b4989e29'}  is already in DB
# id:  {'6319ddde-9025-586a-8767-af59c577be21'}  is already in DB
# id:  {'679c2909-2248-534a-8cf6-341d6e4629f5'}  is already in DB
# ...
# id:  {'e77b9614-973f-51c6-806a-613ff956b85f'}  is already in DB
# id:  {'ac65112b-2b83-59ff-94c0-68788a1b37b9'}  is already in DB
# id:  {'f4a04a4e-d721-5209-b7c3-18c456671525'}  is already in DB
# id:  {'050e4738-345c-54c7-99c5-0fad39d90328'}  is already in DB
# id:  {'773edb01-c698-5d4f-96db-a9cbce4e5b3f'}  is already in DB
# id:  {'0ebe75e3-0279-5981-88f6-766d60cf0474'}  is already in DB
# id:  {'414197b7-5f35-541a-9eaa-98aae5070103'}  is already in DB
# id:  {'0d877300-d6b4-5a11-a6d5-0b047c039774'}  is already in DB
# id:  {'b66ed4ce-c0d9-5b4d-83c4-c06f5bcd2c06'}  is already in DB
# id:  {'9b2dfe6f-9ccc-5ca3-b361-b7005bc1e177'}  is already in DB
# id:  {'c58f6325-84f3-5ff5-8476-baa715a43b56'}  is already in DB
# id:  {'a891a173-e599-5826-8a37-c56676667440'}  is already in DB
# id:  {'3220dbb2-8a1a-51fc-8c75-e36a77969e74'}  is already in DB
# id:  {'d0a56aa8-4f3f-5191-ae6a-7fe2c4b9de18'}  is already in DB
# id:  {'0b735ccd-ed4c-5295-9a89-64cd30fd1a79'}  is already in DB
# id:  {'f9b1c01c-c938-5d62-b07c-5063a50aac0a'}  is already in DB
# id:  {'02986439-cf55-56cf-8199-0a2871abbc90'}  is already in DB
# id:  {'f5419863-8c47-5c72-9e9e-f34fa876f697'}  is already in DB
# id:  {'745192ec-cebe-517a-a634-23aa8fa9219c'}  is already in DB
# id:  {'255ee643-6254-5b97-9615-a38cd3c74b69'}  is already in DB
# id:  {'5aeb42bd-d568-5b20-adf6-8a622dc7a8c7'}  is already in DB
# id:  {'d750e68f-dbae-5d6e-9d5f-1d61ebe699c7'}  is already in DB
# id:  {'7b4befd4-120e-5ea6-b543-b0716b4dad24'}  is already in DB
# id:  {'d23b9393-ab19-5e93-a284-2e33799ea5a2'}  is already in DB
# id:  {'85b67c56-fbc7-5592-b2f0-3634c15bbc01'}  is already in DB
# id:  {'f583c304-fa8c-57da-a945-129d946d30a0'}  is already in DB
# id:  {'4f05a60a-5b32-58b1-86d4-8eb05a6ed02b'}  is already in DB
# id:  {'c0240a43-4c7e-5c14-be73-5f2c6bf10b17'}  is already in DB
# id:  {'fd1ae4b0-7c42-55e8-a988-b56ccf7f6385'}  is already in DB
# id:  {'fbac327a-3228-5c2a-b000-2aa2c7f2aba6'}  is already in DB
# id:  {'c427d7b4-d0d7-5498-adc4-9ad827ade224'}  is already in DB
# id:  {'164ed533-3f70-537f-bb4f-a2a780f67708'}  is already in DB
# id:  {'4fe44d6c-847f-5982-8053-5c712d78bc71'}  is already in DB
# id:  {'e4662e31-d939-5408-aa74-22f852512dda'}  is already in DB
# id:  {'9a7557b6-c46f-56c8-bb1f-ba2bdf651b08'}  is already in DB
# id:  {'42ad320f-c254-566a-89db-25a5fafb69dc'}  is already in DB
# id:  {'3913acc4-9cec-5de8-9d6e-e3fde2f1ae43'}  is already in DB
# id:  {'9df76fbf-da71-52be-baed-0c931abcc2b3'}  is already in DB
# id:  {'d892646a-990e-532a-9b60-6b480307e3ad'}  is already in DB
# id:  {'650f3d95-e118-525c-9992-336cddf4a4b4'}  is already in DB
# id:  {'bbc2ad14-eb6a-5cb9-8457-1053013503a0'}  is already in DB
# id:  {'fd4d32ad-bf94-5be8-8305-e2740cf73aa0'}  is already in DB
# id:  {'f1d3191d-af22-53bd-b330-361bc54b2e92'}  is already in DB
# id:  {'3e17353e-d471-53d4-b4e5-d5c6422cc9e9'}  is already in DB
# id:  {'f96acce0-ad97-5bd4-a062-867d198452f2'}  is already in DB
# id:  {'ab8ff9c7-4b53-5aa3-9ead-c040117143f7'}  is already in DB
# id:  {'b5107e19-6b42-5d45-9a47-4d957324a13a'}  is already in DB
# id:  {'683b7e7c-254c-52dc-ae5c-27d7915d9edc'}  is already in DB
# id:  {'5955c612-9e2e-5857-b0b2-653ba9e57049'}  is already in DB
# id:  {'6349c095-0f05-5da7-a99c-e2b2315a5e91'}  is already in DB
# id:  {'e295ce69-2fe0-58e8-ba8c-75f096672719'}  is already in DB
# id:  {'fca518d1-6557-559f-bd75-927053cf888b'}  is already in DB
# id:  {'b1c57765-3773-5d92-b57c-2fa18d45da69'}  is already in DB
# id:  {'42ec8202-5ad6-54d6-83c3-0c359374fd42'}  is already in DB
# id:  {'f21aac2d-da4d-54d1-839d-9ec660c3a2a9'}  is already in DB
# id:  {'dac18d96-e5b5-5bce-b286-6c36c6fa6227'}  is already in DB
# id:  {'d08e4787-3b4d-5a78-92e5-c29dc76b4555'}  is already in DB
# id:  {'516ee1f7-60cf-55b5-97a9-2b8ab682b10c'}  is already in DB
# id:  {'ef26844a-65c6-526f-a44f-0a235be1e20a'}  is already in DB
# id:  {'5a616895-7b33-54b6-b25f-ff02fbccecf5'}  is already in DB
# id:  {'02fc9ca1-936a-5ac9-860e-a7ef2c2cab57'}  is already in DB
# id:  {'14cc2a57-d5cd-5796-8890-85f54081fec5'}  is already in DB
# id:  {'06ec4faf-aef7-582a-8a97-950a572447d1'}  is already in DB
# id:  {'318e1cdb-fa96-50d9-91ec-f26807ab7e99'}  is already in DB
# id:  {'b56dfb59-daaa-5804-9cbd-e110ab5efbe1'}  is already in DB
# id:  {'fb76743b-c77e-541e-b220-c3e7b8db1ef5'}  is already in DB
# id:  {'41093cc5-a520-5f41-9d17-43d8b96b7068'}  is already in DB
# id:  {'078f98a4-11cd-573d-adb3-72966678513e'}  is already in DB
# id:  {'5f40ee0e-624d-54b5-bb0f-57915c3a6ef7'}  is already in DB
# id:  {'a569136b-a585-5737-a330-fba771f7bbfb'}  is already in DB
# id:  {'de41877b-8522-532f-85c1-2a8ba5ff6996'}  is already in DB
# id:  {'ce727601-319a-5d84-82e5-3e922dd49570'}  is already in DB
# id:  {'7ca708d3-c31b-5cec-a1a8-f06de9e3081c'}  is already in DB
# id:  {'f9a5255f-2640-57e8-bc34-b1be1e26b4e7'}  is already in DB
# id:  {'dd0bef30-f617-507f-96be-03e324b74a97'}  is already in DB
# id:  {'95049bc5-7d0d-52ec-b2c6-ff64f7f759b9'}  is already in DB
# id:  {'22643fbc-3a1a-50bb-b7b5-6546a251c79c'}  is already in DB
# id:  {'da42b1d8-7de6-5e64-b1ea-d41e5c57343e'}  is already in DB
# id:  {'7195a1a5-a72b-5121-98d8-032ba704eb55'}  is already in DB
# id:  {'2c9eec7c-f1ff-5763-a8e6-c0f058508cea'}  is already in DB
# id:  {'9b4c1139-6370-5f0f-87bf-1b1454f1d5dc'}  is already in DB
# id:  {'eacde20f-e52b-58e1-8fba-45996b7febab'}  is already in DB
# id:  {'8fae9eeb-5c06-5def-96b9-5582338bd9b0'}  is already in DB
# id:  {'4ed65058-2235-5cbf-b087-534ee23b1fd6'}  is already in DB
# id:  {'37677ad3-0aa2-5ed7-b4ac-bb79b9e786e7'}  is already in DB
# id:  {'3764efd1-b0b3-5a83-a20e-fb6831092cd6'}  is already in DB
# id:  {'f56006fc-1776-5dd0-9ccb-ff1e89470a8c'}  is already in DB
# id:  {'13cd04a8-4910-562d-babf-86c56f00a75e'}  is already in DB
# id:  {'530a6d71-4764-513b-aabf-f7ad9ea818a6'}  is already in DB
# id:  {'9b0fdc2a-120e-5f92-800c-30d5ac1f7916'}  is already in DB
# id:  {'e996791f-d6c8-587e-a425-f03b43f7fa0a'}  is already in DB
# id:  {'859b703e-59e7-5b52-b529-624450dd6fd8'}  is already in DB
# id:  {'0bff9cd4-5b09-5618-a4a8-20f240dc3a4f'}  is already in DB
# id:  {'f8220e44-acfc-5e20-9ad4-5b843d8cacb4'}  is already in DB
# id:  {'b4d34d36-7f9d-5f40-adcc-3645ac89f606'}  is already in DB
# id:  {'e50f7856-d06c-50c2-8323-54009a3d29ba'}  is already in DB
# id:  {'cb9e245d-133c-54ac-ab51-4ad716f3e2ff'}  is already in DB
# id:  {'4d01ac6b-cb6c-5624-befd-6fa76e947373'}  is already in DB
# id:  {'33d26035-3f16-538b-aea9-11af346a8c53'}  is already in DB
# id:  {'4a12a04f-b1c6-5aa6-b71f-2ebcd3ba64c3'}  is already in DB
# id:  {'22d81e17-820b-5ce9-a980-75e903844d77'}  is already in DB
# id:  {'9c236d9a-de5b-5391-a475-e24c3c8f78a3'}  is already in DB
# id:  {'0a707614-2e7c-509b-ae35-69a5a02c8d09'}  is already in DB
# id:  {'684db6b6-53a4-5f5e-89b0-049f3d165c82'}  is already in DB
# id:  {'ffc84066-9533-52cd-9fb4-1029702a0a86'}  is already in DB
# id:  {'0f3dbaa2-f419-53fc-bfce-a51413ec5cf4'}  is already in DB
# id:  {'a6695ac1-f416-5bbb-8b0f-1260d08e1f8e'}  is already in DB
# id:  {'addaaec1-9329-5e26-9b3f-5f4f392cf92d'}  is already in DB
# id:  {'a226e272-dd2a-5e1a-908d-7131990d8228'}  is already in DB
# id:  {'be3f3a4b-0b36-5c3e-bafa-203f6b361478'}  is already in DB
# id:  {'26a3a587-ee14-579d-9358-e8896dbac95c'}  is already in DB
# id:  {'c81e1673-254e-50c8-b62b-402c7ed71321'}  is already in DB
# id:  {'43c1bbc0-ea31-5d8d-905a-f2c7622553b7'}  is already in DB
# id:  {'360aea3f-95de-563f-a388-054c7b58c7f3'}  is already in DB
# id:  {'c32030e9-fd78-5f75-9cc3-7b9df2b3b258'}  is already in DB
# id:  {'577e311d-6eca-5b8e-9d18-dfc62d23164f'}  is already in DB
# id:  {'059cb176-c61c-59e5-89f1-16d704fbcbd5'}  is already in DB
# id:  {'23e973af-93df-52b2-8bc0-cd9945afce37'}  is already in DB
# id:  {'eeee86e7-20b5-5b9e-abc3-d5857532f602'}  is already in DB
# id:  {'6556c6b9-f85d-5cb1-8b34-95fefc0b7c53'}  is already in DB
# id:  {'9c6f6251-837f-5d7e-bcdd-06791cf1b8bb'}  is already in DB
# id:  {'d3be58df-a25d-578a-b0b5-35c8a6d792a2'}  is already in DB
# id:  {'8222081d-bff7-5f6b-9d05-c0d7838175ea'}  is already in DB
# id:  {'1e340dd8-70d3-5ad1-a67a-8f53f2e2a160'}  is already in DB
# id:  {'a67e5be2-e81f-5ab5-8307-0553b4f23c77'}  is already in DB
# id:  {'7c7ac843-5e26-5a27-b11e-90803bf3a53a'}  is already in DB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2_/bnd0fncj143gc6x61sb7k8mc0000gn/T/ipykernel_14579/2083714428.py in <module>
#      11
#      12     if id_link == 'id is not in DB' :
# ---> 13         earthquakes.create_insert_table(query_insert_eval)
#      14
#      15     else:
#
# /var/folders/2_/bnd0fncj143gc6x61sb7k8mc0000gn/T/ipykernel_14579/3757308799.py in create_insert_table(self, query)
#      30
#      31         try:
# ---> 32             engine.execute(query)
#      33
#      34         except SQLAlchemyError as e:
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     399         if not skip_warning:
#     400             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401         return fn(*args, **kwargs)
#     402
#     403     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3143
#    3144         """
# -> 3145         connection = self.connect(close_with_result=True)
#    3146         return connection.execute(statement, *multiparams, **params)
#    3147
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3202         """
#    3203
# -> 3204         return self._connection_cls(self, close_with_result=close_with_result)
#    3205
#    3206     @util.deprecated(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3281
#    3282         """
# -> 3283         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3284
#    3285
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3248         dialect = self.dialect
#    3249         try:
# -> 3250             return fn()
#    3251         except dialect.dbapi.Error as e:
#    3252             if connection is None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     308
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#     312     def _return_conn(self, record):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     866     def _checkout(cls, pool, threadconns=None, fairy=None):
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#     870             fairy._pool = pool
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     474     @classmethod
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#     478             dbapi_connection = rec.get_connection()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     254         """Called by subclasses to create a new ConnectionRecord."""
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#     258     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     369         self.__pool = pool
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#     373
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     659         try:
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#     663             self.fresh = True
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     588                     if connection is not None:
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#     592         creator = pop_kwarg("creator", connect)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     595     def connect(self, *cargs, **cparams):
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#     599     def create_connect_args(self, url):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in connect(self, sock)
#     611                     while True:
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#     615                             )
#
# ~/opt/anaconda3/lib/python3.9/socket.py in create_connection(address, timeout, source_address)
#     821     host, port = address
#     822     err = None
# --> 823     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     824         af, socktype, proto, canonname, sa = res
#     825         sock = None
#
# ~/opt/anaconda3/lib/python3.9/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     952     # and socket type values to enum constants.
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#     956         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %%
def fstr(template):
    return eval(f"f'{template}'")

def insert_data(df,engine,schema_name, table_name, unique_id):
    
    fields_param_lst = []
    fields_lst = []
    for ele in df.columns:
        if df[ele].dtypes == 'object':
            fields_param_lst.append("{quote}"+'{row["'+f"{ele}"+'"]}'+"{quote}")
        else:
            fields_param_lst.append('{row["'+f"{ele}"+'"]}')
        fields_lst.append(ele)


    fields_param = ", ".join(fields_param_lst)
    fields = ", ".join(fields_lst)
    
    for index, row in df.iterrows():
        
        quote = '"'
        
        # creating the query to insert values into table
        query_insert= "INSERT INTO "+schema_name+"."+table_name+" ({fields}) VALUES ({fields_param});"
        query_insert_eval2 = fstr(query_insert).replace("nan", "null")
        query_insert_eval = fstr(fstr(query_insert)).replace("nan", "null")
        
        id_link = engine.get_id( f'{row[unique_id]}', unique_id , unique_id, table_name)
        
        if id_link == 'id is not in DB' : 
            engine.create_insert_table(query_insert_eval)
            
            print(query_insert,"\n")
            print(query_insert_eval2,"\n")
            print(query_insert_eval)
        else:
            print('id: ',{row[unique_id]}, " is already in DB")

# %%
insert_data(f_earthquakes_sample, earthquakes,'earthquakes','f_earthquakes', 'id_earthquake')
# Out:
# INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ({quote}{row["id_earthquake"]}{quote}, {quote}{row["key_earthquake_gdp"]}{quote}, {quote}{row["time"]}{quote}, {row["year"]}, {row["latitude"]}, {row["longitude"]}, {row["depth"]}, {row["mag"]}, {quote}{row["magType"]}{quote}, {row["nst"]}, {row["gap"]}, {row["dmin"]}, {row["rms"]}, {quote}{row["net"]}{quote}, {quote}{row["id"]}{quote}, {quote}{row["place"]}{quote}, {quote}{row["type"]}{quote}, {row["horizontalError"]}, {row["depthError"]}, {row["magError"]}, {row["magNst"]}, {quote}{row["status"]}{quote}, {quote}{row["locationSource"]}{quote}, {quote}{row["magSource"]}{quote}, {quote}{row["updated_date"]}{quote});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ("65de4a73-61b1-52d9-bdab-428d69fa5c2b", "aaefad2b-5463-536c-902a-2bbcea8d54e0", "2010-07-24 10:03:11", 2010, 46.2013333, -122.18116670000002, 2.314, -0.7, "md", 10.0, 143.0, null, 0.12, "uw", "uw10799568", "Mount St. Helens area, Washington", "earthquake", 0.708, 0.77, 0.01, 3.0, "reviewed", "uw", "uw", "2016-07-22 17:10:23");
# INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ({quote}{row["id_earthquake"]}{quote}, {quote}{row["key_earthquake_gdp"]}{quote}, {quote}{row["time"]}{quote}, {row["year"]}, {row["latitude"]}, {row["longitude"]}, {row["depth"]}, {row["mag"]}, {quote}{row["magType"]}{quote}, {row["nst"]}, {row["gap"]}, {row["dmin"]}, {row["rms"]}, {quote}{row["net"]}{quote}, {quote}{row["id"]}{quote}, {quote}{row["place"]}{quote}, {quote}{row["type"]}{quote}, {row["horizontalError"]}, {row["depthError"]}, {row["magError"]}, {row["magNst"]}, {quote}{row["status"]}{quote}, {quote}{row["locationSource"]}{quote}, {quote}{row["magSource"]}{quote}, {quote}{row["updated_date"]}{quote});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ("65de4a73-61b1-52d9-bdab-428d69fa5c2b", "aaefad2b-5463-536c-902a-2bbcea8d54e0", "2010-07-24 10:03:11", 2010, 46.2013333, -122.18116670000002, 2.314, -0.7, "md", 10.0, 143.0, null, 0.12, "uw", "uw10799568", "Mount St. Helens area, Washington", "earthquake", 0.708, 0.77, 0.01, 3.0, "reviewed", "uw", "uw", "2016-07-22 17:10:23");
# INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ({quote}{row["id_earthquake"]}{quote}, {quote}{row["key_earthquake_gdp"]}{quote}, {quote}{row["time"]}{quote}, {row["year"]}, {row["latitude"]}, {row["longitude"]}, {row["depth"]}, {row["mag"]}, {quote}{row["magType"]}{quote}, {row["nst"]}, {row["gap"]}, {row["dmin"]}, {row["rms"]}, {quote}{row["net"]}{quote}, {quote}{row["id"]}{quote}, {quote}{row["place"]}{quote}, {quote}{row["type"]}{quote}, {row["horizontalError"]}, {row["depthError"]}, {row["magError"]}, {row["magNst"]}, {quote}{row["status"]}{quote}, {quote}{row["locationSource"]}{quote}, {quote}{row["magSource"]}{quote}, {quote}{row["updated_date"]}{quote});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ("65de4a73-61b1-52d9-bdab-428d69fa5c2b", "aaefad2b-5463-536c-902a-2bbcea8d54e0", "2010-07-24 10:03:11", 2010, 46.2013333, -122.18116670000002, 2.314, -0.7, "md", 10.0, 143.0, null, 0.12, "uw", "uw10799568", "Mount St. Helens area, Washington", "earthquake", 0.708, 0.77, 0.01, 3.0, "reviewed", "uw", "uw", "2016-07-22 17:10:23");
# INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ({quote}{row["id_earthquake"]}{quote}, {quote}{row["key_earthquake_gdp"]}{quote}, {quote}{row["time"]}{quote}, {row["year"]}, {row["latitude"]}, {row["longitude"]}, {row["depth"]}, {row["mag"]}, {quote}{row["magType"]}{quote}, {row["nst"]}, {row["gap"]}, {row["dmin"]}, {row["rms"]}, {quote}{row["net"]}{quote}, {quote}{row["id"]}{quote}, {quote}{row["place"]}{quote}, {quote}{row["type"]}{quote}, {row["horizontalError"]}, {row["depthError"]}, {row["magError"]}, {row["magNst"]}, {quote}{row["status"]}{quote}, {quote}{row["locationSource"]}{quote}, {quote}{row["magSource"]}{quote}, {quote}{row["updated_date"]}{quote});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ("65de4a73-61b1-52d9-bdab-428d69fa5c2b", "aaefad2b-5463-536c-902a-2bbcea8d54e0", "2010-07-24 10:03:11", 2010, 46.2013333, -122.18116670000002, 2.314, -0.7, "md", 10.0, 143.0, null, 0.12, "uw", "uw10799568", "Mount St. Helens area, Washington", "earthquake", 0.708, 0.77, 0.01, 3.0, "reviewed", "uw", "uw", "2016-07-22 17:10:23");
# INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ({quote}{row["id_earthquake"]}{quote}, {quote}{row["key_earthquake_gdp"]}{quote}, {quote}{row["time"]}{quote}, {row["year"]}, {row["latitude"]}, {row["longitude"]}, {row["depth"]}, {row["mag"]}, {quote}{row["magType"]}{quote}, {row["nst"]}, {row["gap"]}, {row["dmin"]}, {row["rms"]}, {quote}{row["net"]}{quote}, {quote}{row["id"]}{quote}, {quote}{row["place"]}{quote}, {quote}{row["type"]}{quote}, {row["horizontalError"]}, {row["depthError"]}, {row["magError"]}, {row["magNst"]}, {quote}{row["status"]}{quote}, {quote}{row["locationSource"]}{quote}, {quote}{row["magSource"]}{quote}, {quote}{row["updated_date"]}{quote});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ("65de4a73-61b1-52d9-bdab-428d69fa5c2b", "aaefad2b-5463-536c-902a-2bbcea8d54e0", "2010-07-24 10:03:11", 2010, 46.2013333, -122.18116670000002, 2.314, -0.7, "md", 10.0, 143.0, null, 0.12, "uw", "uw10799568", "Mount St. Helens area, Washington", "earthquake", 0.708, 0.77, 0.01, 3.0, "reviewed", "uw", "uw", "2016-07-22 17:10:23");
# INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ({quote}{row["id_earthquake"]}{quote}, {quote}{row["key_earthquake_gdp"]}{quote}, {quote}{row["time"]}{quote}, {row["year"]}, {row["latitude"]}, {row["longitude"]}, {row["depth"]}, {row["mag"]}, {quote}{row["magType"]}{quote}, {row["nst"]}, {row["gap"]}, {row["dmin"]}, {row["rms"]}, {quote}{row["net"]}{quote}, {quote}{row["id"]}{quote}, {quote}{row["place"]}{quote}, {quote}{row["type"]}{quote}, {row["horizontalError"]}, {row["depthError"]}, {row["magError"]}, {row["magNst"]}, {quote}{row["status"]}{quote}, {quote}{row["locationSource"]}{quote}, {quote}{row["magSource"]}{quote}, {quote}{row["updated_date"]}{quote});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ("65de4a73-61b1-52d9-bdab-428d69fa5c2b", "aaefad2b-5463-536c-902a-2bbcea8d54e0", "2010-07-24 10:03:11", 2010, 46.2013333, -122.18116670000002, 2.314, -0.7, "md", 10.0, 143.0, null, 0.12, "uw", "uw10799568", "Mount St. Helens area, Washington", "earthquake", 0.708, 0.77, 0.01, 3.0, "reviewed", "uw", "uw", "2016-07-22 17:10:23");
# INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ({quote}{row["id_earthquake"]}{quote}, {quote}{row["key_earthquake_gdp"]}{quote}, {quote}{row["time"]}{quote}, {row["year"]}, {row["latitude"]}, {row["longitude"]}, {row["depth"]}, {row["mag"]}, {quote}{row["magType"]}{quote}, {row["nst"]}, {row["gap"]}, {row["dmin"]}, {row["rms"]}, {quote}{row["net"]}{quote}, {quote}{row["id"]}{quote}, {quote}{row["place"]}{quote}, {quote}{row["type"]}{quote}, {row["horizontalError"]}, {row["depthError"]}, {row["magError"]}, {row["magNst"]}, {quote}{row["status"]}{quote}, {quote}{row["locationSource"]}{quote}, {quote}{row["magSource"]}{quote}, {quote}{row["updated_date"]}{quote});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ("65de4a73-61b1-52d9-bdab-428d69fa5c2b", "aaefad2b-5463-536c-902a-2bbcea8d54e0", "2010-07-24 10:03:11", 2010, 46.2013333, -122.18116670000002, 2.314, -0.7, "md", 10.0, 143.0, null, 0.12, "uw", "uw10799568", "Mount St. Helens area, Washington", "earthquake", 0.708, 0.77, 0.01, 3.0, "reviewed", "uw", "uw", "2016-07-22 17:10:23");
# INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ({quote}{row["id_earthquake"]}{quote}, {quote}{row["key_earthquake_gdp"]}{quote}, {quote}{row["time"]}{quote}, {row["year"]}, {row["latitude"]}, {row["longitude"]}, {row["depth"]}, {row["mag"]}, {quote}{row["magType"]}{quote}, {row["nst"]}, {row["gap"]}, {row["dmin"]}, {row["rms"]}, {quote}{row["net"]}{quote}, {quote}{row["id"]}{quote}, {quote}{row["place"]}{quote}, {quote}{row["type"]}{quote}, {row["horizontalError"]}, {row["depthError"]}, {row["magError"]}, {row["magNst"]}, {quote}{row["status"]}{quote}, {quote}{row["locationSource"]}{quote}, {quote}{row["magSource"]}{quote}, {quote}{row["updated_date"]}{quote});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ("65de4a73-61b1-52d9-bdab-428d69fa5c2b", "aaefad2b-5463-536c-902a-2bbcea8d54e0", "2010-07-24 10:03:11", 2010, 46.2013333, -122.18116670000002, 2.314, -0.7, "md", 10.0, 143.0, null, 0.12, "uw", "uw10799568", "Mount St. Helens area, Washington", "earthquake", 0.708, 0.77, 0.01, 3.0, "reviewed", "uw", "uw", "2016-07-22 17:10:23");
# INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ({quote}{row["id_earthquake"]}{quote}, {quote}{row["key_earthquake_gdp"]}{quote}, {quote}{row["time"]}{quote}, {row["year"]}, {row["latitude"]}, {row["longitude"]}, {row["depth"]}, {row["mag"]}, {quote}{row["magType"]}{quote}, {row["nst"]}, {row["gap"]}, {row["dmin"]}, {row["rms"]}, {quote}{row["net"]}{quote}, {quote}{row["id"]}{quote}, {quote}{row["place"]}{quote}, {quote}{row["type"]}{quote}, {row["horizontalError"]}, {row["depthError"]}, {row["magError"]}, {row["magNst"]}, {quote}{row["status"]}{quote}, {quote}{row["locationSource"]}{quote}, {quote}{row["magSource"]}{quote}, {quote}{row["updated_date"]}{quote});
#
# INSERT INTO earthquakes.f_earthquakes (id_earthquake, key_earthquake_gdp, time, year, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource, updated_date) VALUES ("65de4a73-61b1-52d9-bdab-428d69fa5c2b", "aaefad2b-5463-536c-902a-2bbcea8d54e0", "2010-07-24 10:03:11", 2010, 46.2013333, -122.18116670000002, 2.314, -0.7, "md", 10.0, 143.0, null, 0.12, "uw", "uw10799568", "Mount St. Helens area, Washington", "earthquake", 0.708, 0.77, 0.01, 3.0, "reviewed", "uw", "uw", "2016-07-22 17:10:23");
# id:  {'65de4a73-61b1-52d9-bdab-428d69fa5c2b'}  is already in DB

# %%
f_gdp = pd.read_parquet('../data/extraction_layer/f_gdp.parquet', engine='fastparquet')

def fstr(template):
    return eval(f"f'{template}'")

# automatic insert
fields_param_lst = []
fields_lst = []
for ele in f_gdp.columns:
    if f_gdp[ele].dtypes == 'object':
        fields_param_lst.append("{quote}"+'{row["'+f"{ele}"+'"]}'+"{quote}")
    else:
        fields_param_lst.append('{row["'+f"{ele}"+'"]}')
    fields_lst.append(ele)

fields_param = ", ".join(fields_param_lst)
fields = ", ".join(fields_lst)


print('  ---> start inserting data - GDP')
for index, row in tqdm(f_gdp.iterrows(), total=f_gdp.shape[0]):

    quote = '"'

    # creating the query to insert values into table
    query_insert = "INSERT INTO earthquakes.f_earthquakes ({fields}) VALUES ({fields_param});"
    query_insert_eval = fstr(fstr(query_insert)).replace("nan", "null")

    id_link = earthquakes.get_id(f'{row["id_gdp"]}', "id_gdp", "id_gdp", "f_gdp")

    if id_link == 'id is not in DB':
        #earthquakes.create_insert_table(query_insert_eval)
        pass

    else:
        pass
        #print('id: ', {row['`id_gdp`']}, " is already in DB")

print('  ---> finish inserting data - GDP \n')
# Out:
#   ---> start inserting data - GDP
# 100%|██████████████████████████████████████| 1250/1250 [00:06<00:00, 203.69it/s]
#   ---> finish inserting data - GDP
